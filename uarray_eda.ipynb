# %%
# !head -n 5 data_set_HL60_U937_NB4_Jurkat.txt
# Out:
# Gene Description	Gene Accession Number	HL60_0_hrs	call	HL60_0.5_hrs	call	HL60_4_hrs	call	HL60_24_hrs	call	U937_0_hrs	call	U937_0.5_hrs	call	U937_4_hrs	call	U937_24_hrs	call	NB4_0_hrs	call	NB4_5.5_hrs	call	NB4_24_hrs	call	NB4_48_hrs	call	NB4_72_hrs	call	Jurkat_0_hrs	call	Jurkat_0.5_hrs	call	Jurkat_4_hrs	call	Jurkat_24_hrs call
#
#
# "BioB (spiked control)"	BioB	7	A	-12	A	3	A	19	A	254	P	3	A	4	A	247	P	-4	A	-4	A	-11	A	-6	A	-7	A	-5	A	-5	A	-2	A	-3	A
# "BioC (spiked control)"	BioC	62	P	5	A	75	P	107	P	596	P	41	P	46	P	606	P	3	A	1	A	4	A	-5	A	2	A	1	A	3	A	3	A	-3	A

# %%
import pandas
uarray = pandas.read_csv("data_set_HL60_U937_NB4_Jurkat.txt", sep='\t')

# %%
uarray
# Out:
#                                                    Gene Description  \
# BioB (spiked control)                                          BioB
# BioC (spiked control)                                          BioC
# BioD (spiked control)                                          BioD
# CYP3A3 Cytochrome P450 IIIA3 (nifedipine oxidas...         D00003_f
# CYP3A3 Cytochrome P450 IIIA3 (nifedipine oxidas...         D00003_i
# CYP3A3 Cytochrome P450 IIIA3 (nifedipine oxidas...       D00003_r_i
# PRNP Prion protein (p27-30) (Creutzfeld-Jakob d...           D00015
# LTA Lymphotoxin alpha (formerly tumor necrosis ...           D00102
# ADH2 Alcohol dehydrogenase 2 (class I), beta po...           D00137
# CYP2C9 Cytochrome P450, subfamily IIC (mephenyt...           D00173
# CYC1 Cytochrome c-1                                          D00265
# ELASTASE IIIA PRECURSOR                                      D00306
# CYP3A7 Cytochrome P450 IIIA7 (P450-HFLa)                     D00408
# TYMS Thymidylate synthase                                    D00596
# FECH Ferrochelatase (protoporphyria)                         D00726
# T-CELL ANTIGEN CD7 PRECURSOR                                 D00749
# PSMA3 Proteasome component C3                              D00760_f
# PSMA5 Proteasome component C5                              D00761_f
# PROTEASOME COMPONENT C8                                    D00762_f
# GAPD Glyceraldehyde-3-phosphate dehydrogenase                D00763
# PRPS1 Phosphoribosyl pyrophosphate synthetase s...           D00860
# FACL1 Long chain fatty acid acyl-coA ligase                  D10040
# PTAFR Platelet activating factor receptor                    D10202
# POU1F1 POU domain, class 1, transcription facto...           D10216
# ACAT1 Acetyl-Coenzyme A acetyltransferase 2 (ac...           D10511
# MACS Myristoylated alanine-rich C-kinase substrate         D10522_i
# MACS Myristoylated alanine-rich C-kinase substrate         D10522_r
# OGDH Oxoglutarate dehydrogenase (lipoamide)                  D10523
# MPZ Myelin protein zero (Charcot-Marie-Tooth ne...           D10537
# CBFA2 Core-binding factor, runt domain, alpha s...           D10570
# ...                                                             ...
# FAS Del 2 mRNA                                               Z47994
# mRNA encoding GPI-anchored protein p137                      Z48042
# MOG Myelin oligodendrocyte glycoprotein {altern...           Z48051
# PXR1 Peroxisome receptor 1                                   Z48054
# SDC1 Syndecan 1                                              Z48199
# GCKR Glucokinase regulator                                 Z48475_f
# GCKR Glucokinase regulator                                 Z48475_i
# GCKR Glucokinase regulator                               Z48475_r_i
# MT-MMP protein                                               Z48481
# MMP2 Matrix metalloproteinase 2                              Z48482
# Protein tyrosine phosphatase                                 Z48541
# Sp17 gene                                                    Z48570
# mRNA (ocular albinism type 1 related)                        Z48804
# BMPR-II                                                      Z48923
# HISTONE H3.3                                                 Z48950
# Spermine synthase                                            Z49099
# OBF-1 mRNA for octamer binding factor 1                      Z49194
# RNA polymerase II subunit (hsRPB8) mRNA                      Z49199
# P2Y1 purinoceptor mRNA, long form                            Z49205
# Chemokine HCC-1                                            Z49269_f
# Chemokine HCC-1                                            Z49269_i
# Chemokine HCC-1                                          Z49269_r_i
# GUC1A2 Guanylate cyclase 1, soluble, alpha 2                 Z50053
# NAD(P) transhydrogenase                                    Z50101_i
# NAD(P) transhydrogenase                                    Z50101_r
# Thimet oligopeptidase (metalloproteinase)                    Z50115
# No cluster in current Unigene and no Genbank en...           Z50194
# GCAP-II/uroguanylin precursor                                Z50753
# BETA-DEFENSIN 1 PRECURSOR                                  Z50788_f
# cre (spiked control)                                            cre
#
#                                                     Gene Accession Number  \
# BioB (spiked control)                                                   7
# BioC (spiked control)                                                  62
# BioD (spiked control)                                                 372
# CYP3A3 Cytochrome P450 IIIA3 (nifedipine oxidas...                      8
# CYP3A3 Cytochrome P450 IIIA3 (nifedipine oxidas...                     -7
# CYP3A3 Cytochrome P450 IIIA3 (nifedipine oxidas...                      5
# PRNP Prion protein (p27-30) (Creutzfeld-Jakob d...                     13
# LTA Lymphotoxin alpha (formerly tumor necrosis ...                      5
# ADH2 Alcohol dehydrogenase 2 (class I), beta po...                      7
# CYP2C9 Cytochrome P450, subfamily IIC (mephenyt...                      4
# CYC1 Cytochrome c-1                                                   411
# ELASTASE IIIA PRECURSOR                                                 1
# CYP3A7 Cytochrome P450 IIIA7 (P450-HFLa)                                3
# TYMS Thymidylate synthase                                             165
# FECH Ferrochelatase (protoporphyria)                                   54
# T-CELL ANTIGEN CD7 PRECURSOR                                           37
# PSMA3 Proteasome component C3                                         105
# PSMA5 Proteasome component C5                                        1266
# PROTEASOME COMPONENT C8                                               889
# GAPD Glyceraldehyde-3-phosphate dehydrogenase                         533
# PRPS1 Phosphoribosyl pyrophosphate synthetase s...                     76
# FACL1 Long chain fatty acid acyl-coA ligase                            50
# PTAFR Platelet activating factor receptor                               9
# POU1F1 POU domain, class 1, transcription facto...                     -5
# ACAT1 Acetyl-Coenzyme A acetyltransferase 2 (ac...                    139
# MACS Myristoylated alanine-rich C-kinase substrate                     -3
# MACS Myristoylated alanine-rich C-kinase substrate                     -1
# OGDH Oxoglutarate dehydrogenase (lipoamide)                            66
# MPZ Myelin protein zero (Charcot-Marie-Tooth ne...                      9
# CBFA2 Core-binding factor, runt domain, alpha s...                    -10
# ...                                                                   ...
# FAS Del 2 mRNA                                                         -1
# mRNA encoding GPI-anchored protein p137                               197
# MOG Myelin oligodendrocyte glycoprotein {altern...                      2
# PXR1 Peroxisome receptor 1                                             29
# SDC1 Syndecan 1                                                       -19
# GCKR Glucokinase regulator                                             17
# GCKR Glucokinase regulator                                             31
# GCKR Glucokinase regulator                                            -72
# MT-MMP protein                                                        -34
# MMP2 Matrix metalloproteinase 2                                       -35
# Protein tyrosine phosphatase                                           24
# Sp17 gene                                                              11
# mRNA (ocular albinism type 1 related)                                   7
# BMPR-II                                                                24
# HISTONE H3.3                                                          335
# Spermine synthase                                                      83
# OBF-1 mRNA for octamer binding factor 1                                 5
# RNA polymerase II subunit (hsRPB8) mRNA                               132
# P2Y1 purinoceptor mRNA, long form                                       9
# Chemokine HCC-1                                                        14
# Chemokine HCC-1                                                        -9
# Chemokine HCC-1                                                        22
# GUC1A2 Guanylate cyclase 1, soluble, alpha 2                           -2
# NAD(P) transhydrogenase                                                37
# NAD(P) transhydrogenase                                                93
# Thimet oligopeptidase (metalloproteinase)                             -11
# No cluster in current Unigene and no Genbank en...                    -10
# GCAP-II/uroguanylin precursor                                          13
# BETA-DEFENSIN 1 PRECURSOR                                              -5
# cre (spiked control)                                                  871
#
#                                                    HL60_0_hrs  call  \
# BioB (spiked control)                                       A   -12
# BioC (spiked control)                                       P     5
# BioD (spiked control)                                       P   143
# CYP3A3 Cytochrome P450 IIIA3 (nifedipine oxidas...          A    28
# CYP3A3 Cytochrome P450 IIIA3 (nifedipine oxidas...          A    36
# CYP3A3 Cytochrome P450 IIIA3 (nifedipine oxidas...          A    -8
# PRNP Prion protein (p27-30) (Creutzfeld-Jakob d...          A     8
# LTA Lymphotoxin alpha (formerly tumor necrosis ...          A   -12
# ADH2 Alcohol dehydrogenase 2 (class I), beta po...          A    -1
# CYP2C9 Cytochrome P450, subfamily IIC (mephenyt...          A    14
# CYC1 Cytochrome c-1                                         P   413
# ELASTASE IIIA PRECURSOR                                     A   -11
# CYP3A7 Cytochrome P450 IIIA7 (P450-HFLa)                    A    -2
# TYMS Thymidylate synthase                                   P   273
# FECH Ferrochelatase (protoporphyria)                        P    82
# T-CELL ANTIGEN CD7 PRECURSOR                                A    15
# PSMA3 Proteasome component C3                               P   118
# PSMA5 Proteasome component C5                               P  1305
# PROTEASOME COMPONENT C8                                     P   824
# GAPD Glyceraldehyde-3-phosphate dehydrogenase               P   554
# PRPS1 Phosphoribosyl pyrophosphate synthetase s...          P    92
# FACL1 Long chain fatty acid acyl-coA ligase                 P    57
# PTAFR Platelet activating factor receptor                   A     6
# POU1F1 POU domain, class 1, transcription facto...          A     1
# ACAT1 Acetyl-Coenzyme A acetyltransferase 2 (ac...          P   212
# MACS Myristoylated alanine-rich C-kinase substrate          A     1
# MACS Myristoylated alanine-rich C-kinase substrate          A     1
# OGDH Oxoglutarate dehydrogenase (lipoamide)                 P   106
# MPZ Myelin protein zero (Charcot-Marie-Tooth ne...          A    24
# CBFA2 Core-binding factor, runt domain, alpha s...          A    -2
# ...                                                       ...   ...
# FAS Del 2 mRNA                                              A     5
# mRNA encoding GPI-anchored protein p137                     P   147
# MOG Myelin oligodendrocyte glycoprotein {altern...          A    10
# PXR1 Peroxisome receptor 1                                  M   -17
# SDC1 Syndecan 1                                             A   -17
# GCKR Glucokinase regulator                                  A    48
# GCKR Glucokinase regulator                                  M    60
# GCKR Glucokinase regulator                                  A  -245
# MT-MMP protein                                              A   -19
# MMP2 Matrix metalloproteinase 2                             A    15
# Protein tyrosine phosphatase                                A    72
# Sp17 gene                                                   P     4
# mRNA (ocular albinism type 1 related)                       A     4
# BMPR-II                                                     M    17
# HISTONE H3.3                                                P   384
# Spermine synthase                                           P    60
# OBF-1 mRNA for octamer binding factor 1                     A     1
# RNA polymerase II subunit (hsRPB8) mRNA                     P   256
# P2Y1 purinoceptor mRNA, long form                           A    20
# Chemokine HCC-1                                             A    37
# Chemokine HCC-1                                             A    18
# Chemokine HCC-1                                             A    -3
# GUC1A2 Guanylate cyclase 1, soluble, alpha 2                A     3
# NAD(P) transhydrogenase                                     P    39
# NAD(P) transhydrogenase                                     P    56
# Thimet oligopeptidase (metalloproteinase)                   A   -31
# No cluster in current Unigene and no Genbank en...          A    -6
# GCAP-II/uroguanylin precursor                               A     4
# BETA-DEFENSIN 1 PRECURSOR                                   A    -5
# cre (spiked control)                                        P   296
#
#                                                    HL60_0.5_hrs  call.1  \
# BioB (spiked control)                                         A       3
# BioC (spiked control)                                         A      75
# BioD (spiked control)                                         P     405
# CYP3A3 Cytochrome P450 IIIA3 (nifedipine oxidas...            P       8
# CYP3A3 Cytochrome P450 IIIA3 (nifedipine oxidas...            P       5
# CYP3A3 Cytochrome P450 IIIA3 (nifedipine oxidas...            A       4
# PRNP Prion protein (p27-30) (Creutzfeld-Jakob d...            A      24
# LTA Lymphotoxin alpha (formerly tumor necrosis ...            A      -8
# ADH2 Alcohol dehydrogenase 2 (class I), beta po...            A       3
# CYP2C9 Cytochrome P450, subfamily IIC (mephenyt...            A       0
# CYC1 Cytochrome c-1                                           P     468
# ELASTASE IIIA PRECURSOR                                       A       3
# CYP3A7 Cytochrome P450 IIIA7 (P450-HFLa)                      A      11
# TYMS Thymidylate synthase                                     P     260
# FECH Ferrochelatase (protoporphyria)                          P      52
# T-CELL ANTIGEN CD7 PRECURSOR                                  A       7
# PSMA3 Proteasome component C3                                 P     132
# PSMA5 Proteasome component C5                                 P    1277
# PROTEASOME COMPONENT C8                                       P     652
# GAPD Glyceraldehyde-3-phosphate dehydrogenase                 P     589
# PRPS1 Phosphoribosyl pyrophosphate synthetase s...            P      69
# FACL1 Long chain fatty acid acyl-coA ligase                   P     122
# PTAFR Platelet activating factor receptor                     A       7
# POU1F1 POU domain, class 1, transcription facto...            A       3
# ACAT1 Acetyl-Coenzyme A acetyltransferase 2 (ac...            P     187
# MACS Myristoylated alanine-rich C-kinase substrate            A       5
# MACS Myristoylated alanine-rich C-kinase substrate            A       2
# OGDH Oxoglutarate dehydrogenase (lipoamide)                   P      60
# MPZ Myelin protein zero (Charcot-Marie-Tooth ne...            P      30
# CBFA2 Core-binding factor, runt domain, alpha s...            A       0
# ...                                                         ...     ...
# FAS Del 2 mRNA                                                A      -2
# mRNA encoding GPI-anchored protein p137                       P     304
# MOG Myelin oligodendrocyte glycoprotein {altern...            A       9
# PXR1 Peroxisome receptor 1                                    A      10
# SDC1 Syndecan 1                                               A     -16
# GCKR Glucokinase regulator                                    M      31
# GCKR Glucokinase regulator                                    P      67
# GCKR Glucokinase regulator                                    A    -149
# MT-MMP protein                                                A     -17
# MMP2 Matrix metalloproteinase 2                               A       1
# Protein tyrosine phosphatase                                  P      86
# Sp17 gene                                                     A      12
# mRNA (ocular albinism type 1 related)                         A       1
# BMPR-II                                                       A      18
# HISTONE H3.3                                                  P     485
# Spermine synthase                                             P      76
# OBF-1 mRNA for octamer binding factor 1                       A      -4
# RNA polymerase II subunit (hsRPB8) mRNA                       P     252
# P2Y1 purinoceptor mRNA, long form                             A       3
# Chemokine HCC-1                                               A       3
# Chemokine HCC-1                                               A      17
# Chemokine HCC-1                                               A      55
# GUC1A2 Guanylate cyclase 1, soluble, alpha 2                  A       5
# NAD(P) transhydrogenase                                       P     -36
# NAD(P) transhydrogenase                                       P       6
# Thimet oligopeptidase (metalloproteinase)                     A     -22
# No cluster in current Unigene and no Genbank en...            A      18
# GCAP-II/uroguanylin precursor                                 A       2
# BETA-DEFENSIN 1 PRECURSOR                                     A       1
# cre (spiked control)                                          P    1004
#
#                                                    HL60_4_hrs  call.2  \
# BioB (spiked control)                                       A      19
# BioC (spiked control)                                       P     107
# BioD (spiked control)                                       P     551
# CYP3A3 Cytochrome P450 IIIA3 (nifedipine oxidas...          A      27
# CYP3A3 Cytochrome P450 IIIA3 (nifedipine oxidas...          A      41
# CYP3A3 Cytochrome P450 IIIA3 (nifedipine oxidas...          A       1
# PRNP Prion protein (p27-30) (Creutzfeld-Jakob d...          P      44
# LTA Lymphotoxin alpha (formerly tumor necrosis ...          A      -6
# ADH2 Alcohol dehydrogenase 2 (class I), beta po...          A       3
# CYP2C9 Cytochrome P450, subfamily IIC (mephenyt...          A      -2
# CYC1 Cytochrome c-1                                         P     136
# ELASTASE IIIA PRECURSOR                                     A      13
# CYP3A7 Cytochrome P450 IIIA7 (P450-HFLa)                    A      10
# TYMS Thymidylate synthase                                   P      35
# FECH Ferrochelatase (protoporphyria)                        P      22
# T-CELL ANTIGEN CD7 PRECURSOR                                M      16
# PSMA3 Proteasome component C3                               P     159
# PSMA5 Proteasome component C5                               P     820
# PROTEASOME COMPONENT C8                                     P     364
# GAPD Glyceraldehyde-3-phosphate dehydrogenase               P     272
# PRPS1 Phosphoribosyl pyrophosphate synthetase s...          P      25
# FACL1 Long chain fatty acid acyl-coA ligase                 P      51
# PTAFR Platelet activating factor receptor                   A       6
# POU1F1 POU domain, class 1, transcription facto...          A     -15
# ACAT1 Acetyl-Coenzyme A acetyltransferase 2 (ac...          P      12
# MACS Myristoylated alanine-rich C-kinase substrate          A       0
# MACS Myristoylated alanine-rich C-kinase substrate          A       0
# OGDH Oxoglutarate dehydrogenase (lipoamide)                 P      84
# MPZ Myelin protein zero (Charcot-Marie-Tooth ne...          A      30
# CBFA2 Core-binding factor, runt domain, alpha s...          A     -12
# ...                                                       ...     ...
# FAS Del 2 mRNA                                              A       7
# mRNA encoding GPI-anchored protein p137                     P     117
# MOG Myelin oligodendrocyte glycoprotein {altern...          A      17
# PXR1 Peroxisome receptor 1                                  A      30
# SDC1 Syndecan 1                                             A      -1
# GCKR Glucokinase regulator                                  P      30
# GCKR Glucokinase regulator                                  P      56
# GCKR Glucokinase regulator                                  A    -174
# MT-MMP protein                                              A     323
# MMP2 Matrix metalloproteinase 2                             A     -51
# Protein tyrosine phosphatase                                P      86
# Sp17 gene                                                   A      30
# mRNA (ocular albinism type 1 related)                       A       0
# BMPR-II                                                     A      -4
# HISTONE H3.3                                                P     339
# Spermine synthase                                           P     107
# OBF-1 mRNA for octamer binding factor 1                     A       1
# RNA polymerase II subunit (hsRPB8) mRNA                     P     105
# P2Y1 purinoceptor mRNA, long form                           A      13
# Chemokine HCC-1                                             A      14
# Chemokine HCC-1                                             A      37
# Chemokine HCC-1                                             P     -42
# GUC1A2 Guanylate cyclase 1, soluble, alpha 2                A      -1
# NAD(P) transhydrogenase                                     A      20
# NAD(P) transhydrogenase                                     A      87
# Thimet oligopeptidase (metalloproteinase)                   A     -19
# No cluster in current Unigene and no Genbank en...          P      40
# GCAP-II/uroguanylin precursor                               A       6
# BETA-DEFENSIN 1 PRECURSOR                                   A      -8
# cre (spiked control)                                        P    1380
#
#                                                    HL60_24_hrs  call.3  \
# BioB (spiked control)                                        A     254
# BioC (spiked control)                                        P     596
# BioD (spiked control)                                        P     752
# CYP3A3 Cytochrome P450 IIIA3 (nifedipine oxidas...           A       6
# CYP3A3 Cytochrome P450 IIIA3 (nifedipine oxidas...           P       2
# CYP3A3 Cytochrome P450 IIIA3 (nifedipine oxidas...           A      -5
# PRNP Prion protein (p27-30) (Creutzfeld-Jakob d...           P      32
# LTA Lymphotoxin alpha (formerly tumor necrosis ...           A       7
# ADH2 Alcohol dehydrogenase 2 (class I), beta po...           A       1
# CYP2C9 Cytochrome P450, subfamily IIC (mephenyt...           A      -1
# CYC1 Cytochrome c-1                                          P     322
# ELASTASE IIIA PRECURSOR                                      A     -21
# CYP3A7 Cytochrome P450 IIIA7 (P450-HFLa)                     P      -3
# TYMS Thymidylate synthase                                    P     808
# FECH Ferrochelatase (protoporphyria)                         P      13
# T-CELL ANTIGEN CD7 PRECURSOR                                 A      13
# PSMA3 Proteasome component C3                                P     136
# PSMA5 Proteasome component C5                                P     635
# PROTEASOME COMPONENT C8                                      P     476
# GAPD Glyceraldehyde-3-phosphate dehydrogenase                P     366
# PRPS1 Phosphoribosyl pyrophosphate synthetase s...           M      61
# FACL1 Long chain fatty acid acyl-coA ligase                  P      29
# PTAFR Platelet activating factor receptor                    A       2
# POU1F1 POU domain, class 1, transcription facto...           A       1
# ACAT1 Acetyl-Coenzyme A acetyltransferase 2 (ac...           M     130
# MACS Myristoylated alanine-rich C-kinase substrate           A      57
# MACS Myristoylated alanine-rich C-kinase substrate           A      38
# OGDH Oxoglutarate dehydrogenase (lipoamide)                  A      40
# MPZ Myelin protein zero (Charcot-Marie-Tooth ne...           P      23
# CBFA2 Core-binding factor, runt domain, alpha s...           A       3
# ...                                                        ...     ...
# FAS Del 2 mRNA                                               A       0
# mRNA encoding GPI-anchored protein p137                      P      32
# MOG Myelin oligodendrocyte glycoprotein {altern...           P       4
# PXR1 Peroxisome receptor 1                                   P       7
# SDC1 Syndecan 1                                              A      -2
# GCKR Glucokinase regulator                                   P       2
# GCKR Glucokinase regulator                                   P       7
# GCKR Glucokinase regulator                                   A     -30
# MT-MMP protein                                               P      -5
# MMP2 Matrix metalloproteinase 2                              A     -15
# Protein tyrosine phosphatase                                 P      64
# Sp17 gene                                                    P       5
# mRNA (ocular albinism type 1 related)                        A      10
# BMPR-II                                                      A       9
# HISTONE H3.3                                                 P     305
# Spermine synthase                                            P      40
# OBF-1 mRNA for octamer binding factor 1                      A       0
# RNA polymerase II subunit (hsRPB8) mRNA                      P     196
# P2Y1 purinoceptor mRNA, long form                            A      -1
# Chemokine HCC-1                                              A      12
# Chemokine HCC-1                                              A      -4
# Chemokine HCC-1                                              A      11
# GUC1A2 Guanylate cyclase 1, soluble, alpha 2                 A       4
# NAD(P) transhydrogenase                                      P      33
# NAD(P) transhydrogenase                                      P      44
# Thimet oligopeptidase (metalloproteinase)                    A       4
# No cluster in current Unigene and no Genbank en...           P       1
# GCAP-II/uroguanylin precursor                                A      35
# BETA-DEFENSIN 1 PRECURSOR                                    A       7
# cre (spiked control)                                         P    4018
#
#                                                            ...          \
# BioB (spiked control)                                      ...
# BioC (spiked control)                                      ...
# BioD (spiked control)                                      ...
# CYP3A3 Cytochrome P450 IIIA3 (nifedipine oxidas...         ...
# CYP3A3 Cytochrome P450 IIIA3 (nifedipine oxidas...         ...
# CYP3A3 Cytochrome P450 IIIA3 (nifedipine oxidas...         ...
# PRNP Prion protein (p27-30) (Creutzfeld-Jakob d...         ...
# LTA Lymphotoxin alpha (formerly tumor necrosis ...         ...
# ADH2 Alcohol dehydrogenase 2 (class I), beta po...         ...
# CYP2C9 Cytochrome P450, subfamily IIC (mephenyt...         ...
# CYC1 Cytochrome c-1                                        ...
# ELASTASE IIIA PRECURSOR                                    ...
# CYP3A7 Cytochrome P450 IIIA7 (P450-HFLa)                   ...
# TYMS Thymidylate synthase                                  ...
# FECH Ferrochelatase (protoporphyria)                       ...
# T-CELL ANTIGEN CD7 PRECURSOR                               ...
# PSMA3 Proteasome component C3                              ...
# PSMA5 Proteasome component C5                              ...
# PROTEASOME COMPONENT C8                                    ...
# GAPD Glyceraldehyde-3-phosphate dehydrogenase              ...
# PRPS1 Phosphoribosyl pyrophosphate synthetase s...         ...
# FACL1 Long chain fatty acid acyl-coA ligase                ...
# PTAFR Platelet activating factor receptor                  ...
# POU1F1 POU domain, class 1, transcription facto...         ...
# ACAT1 Acetyl-Coenzyme A acetyltransferase 2 (ac...         ...
# MACS Myristoylated alanine-rich C-kinase substrate         ...
# MACS Myristoylated alanine-rich C-kinase substrate         ...
# OGDH Oxoglutarate dehydrogenase (lipoamide)                ...
# MPZ Myelin protein zero (Charcot-Marie-Tooth ne...         ...
# CBFA2 Core-binding factor, runt domain, alpha s...         ...
# ...                                                        ...
# FAS Del 2 mRNA                                             ...
# mRNA encoding GPI-anchored protein p137                    ...
# MOG Myelin oligodendrocyte glycoprotein {altern...         ...
# PXR1 Peroxisome receptor 1                                 ...
# SDC1 Syndecan 1                                            ...
# GCKR Glucokinase regulator                                 ...
# GCKR Glucokinase regulator                                 ...
# GCKR Glucokinase regulator                                 ...
# MT-MMP protein                                             ...
# MMP2 Matrix metalloproteinase 2                            ...
# Protein tyrosine phosphatase                               ...
# Sp17 gene                                                  ...
# mRNA (ocular albinism type 1 related)                      ...
# BMPR-II                                                    ...
# HISTONE H3.3                                               ...
# Spermine synthase                                          ...
# OBF-1 mRNA for octamer binding factor 1                    ...
# RNA polymerase II subunit (hsRPB8) mRNA                    ...
# P2Y1 purinoceptor mRNA, long form                          ...
# Chemokine HCC-1                                            ...
# Chemokine HCC-1                                            ...
# Chemokine HCC-1                                            ...
# GUC1A2 Guanylate cyclase 1, soluble, alpha 2               ...
# NAD(P) transhydrogenase                                    ...
# NAD(P) transhydrogenase                                    ...
# Thimet oligopeptidase (metalloproteinase)                  ...
# No cluster in current Unigene and no Genbank en...         ...
# GCAP-II/uroguanylin precursor                              ...
# BETA-DEFENSIN 1 PRECURSOR                                  ...
# cre (spiked control)                                       ...
#
#                                                    call.11  NB4_72_hrs  \
# BioB (spiked control)                                   -7           A
# BioC (spiked control)                                    2           A
# BioD (spiked control)                                  277           P
# CYP3A3 Cytochrome P450 IIIA3 (nifedipine oxidas...       7           A
# CYP3A3 Cytochrome P450 IIIA3 (nifedipine oxidas...      13           A
# CYP3A3 Cytochrome P450 IIIA3 (nifedipine oxidas...      14           M
# PRNP Prion protein (p27-30) (Creutzfeld-Jakob d...      10           A
# LTA Lymphotoxin alpha (formerly tumor necrosis ...      -6           A
# ADH2 Alcohol dehydrogenase 2 (class I), beta po...       7           A
# CYP2C9 Cytochrome P450, subfamily IIC (mephenyt...       5           A
# CYC1 Cytochrome c-1                                    460           P
# ELASTASE IIIA PRECURSOR                                 -6           A
# CYP3A7 Cytochrome P450 IIIA7 (P450-HFLa)                -3           A
# TYMS Thymidylate synthase                              379           P
# FECH Ferrochelatase (protoporphyria)                    63           P
# T-CELL ANTIGEN CD7 PRECURSOR                            14           A
# PSMA3 Proteasome component C3                          160           P
# PSMA5 Proteasome component C5                          330           P
# PROTEASOME COMPONENT C8                                272           P
# GAPD Glyceraldehyde-3-phosphate dehydrogenase          360           P
# PRPS1 Phosphoribosyl pyrophosphate synthetase s...      34           P
# FACL1 Long chain fatty acid acyl-coA ligase            896           P
# PTAFR Platelet activating factor receptor               28           P
# POU1F1 POU domain, class 1, transcription facto...       0           A
# ACAT1 Acetyl-Coenzyme A acetyltransferase 2 (ac...      52           P
# MACS Myristoylated alanine-rich C-kinase substrate     276           P
# MACS Myristoylated alanine-rich C-kinase substrate     262           P
# OGDH Oxoglutarate dehydrogenase (lipoamide)             50           P
# MPZ Myelin protein zero (Charcot-Marie-Tooth ne...      41           P
# CBFA2 Core-binding factor, runt domain, alpha s...      -5           A
# ...                                                    ...         ...
# FAS Del 2 mRNA                                           0           A
# mRNA encoding GPI-anchored protein p137                122           P
# MOG Myelin oligodendrocyte glycoprotein {altern...       1           A
# PXR1 Peroxisome receptor 1                              11           A
# SDC1 Syndecan 1                                        -17           A
# GCKR Glucokinase regulator                              21           P
# GCKR Glucokinase regulator                              25           M
# GCKR Glucokinase regulator                             -39           A
# MT-MMP protein                                          -3           A
# MMP2 Matrix metalloproteinase 2                        -31           A
# Protein tyrosine phosphatase                            61           P
# Sp17 gene                                               -4           A
# mRNA (ocular albinism type 1 related)                   13           A
# BMPR-II                                                  3           A
# HISTONE H3.3                                           313           P
# Spermine synthase                                      108           P
# OBF-1 mRNA for octamer binding factor 1                 -1           A
# RNA polymerase II subunit (hsRPB8) mRNA                113           P
# P2Y1 purinoceptor mRNA, long form                        7           A
# Chemokine HCC-1                                         15           A
# Chemokine HCC-1                                          0           A
# Chemokine HCC-1                                          0           A
# GUC1A2 Guanylate cyclase 1, soluble, alpha 2             1           A
# NAD(P) transhydrogenase                                 29           P
# NAD(P) transhydrogenase                                 27           P
# Thimet oligopeptidase (metalloproteinase)              -10           A
# No cluster in current Unigene and no Genbank en...      30           P
# GCAP-II/uroguanylin precursor                           25           A
# BETA-DEFENSIN 1 PRECURSOR                                2           A
# cre (spiked control)                                  4586           P
#
#                                                    call.12  Jurkat_0_hrs  \
# BioB (spiked control)                                   -5             A
# BioC (spiked control)                                    1             A
# BioD (spiked control)                                  210             P
# CYP3A3 Cytochrome P450 IIIA3 (nifedipine oxidas...       1             A
# CYP3A3 Cytochrome P450 IIIA3 (nifedipine oxidas...       6             A
# CYP3A3 Cytochrome P450 IIIA3 (nifedipine oxidas...       6             A
# PRNP Prion protein (p27-30) (Creutzfeld-Jakob d...      11             P
# LTA Lymphotoxin alpha (formerly tumor necrosis ...      -9             A
# ADH2 Alcohol dehydrogenase 2 (class I), beta po...       3             A
# CYP2C9 Cytochrome P450, subfamily IIC (mephenyt...       3             A
# CYC1 Cytochrome c-1                                    216             P
# ELASTASE IIIA PRECURSOR                                -13             A
# CYP3A7 Cytochrome P450 IIIA7 (P450-HFLa)                 5             P
# TYMS Thymidylate synthase                             1256             P
# FECH Ferrochelatase (protoporphyria)                   163             P
# T-CELL ANTIGEN CD7 PRECURSOR                           216             P
# PSMA3 Proteasome component C3                          249             P
# PSMA5 Proteasome component C5                          782             P
# PROTEASOME COMPONENT C8                                998             P
# GAPD Glyceraldehyde-3-phosphate dehydrogenase          585             P
# PRPS1 Phosphoribosyl pyrophosphate synthetase s...     254             P
# FACL1 Long chain fatty acid acyl-coA ligase             13             P
# PTAFR Platelet activating factor receptor                2             A
# POU1F1 POU domain, class 1, transcription facto...       3             A
# ACAT1 Acetyl-Coenzyme A acetyltransferase 2 (ac...     118             P
# MACS Myristoylated alanine-rich C-kinase substrate       4             A
# MACS Myristoylated alanine-rich C-kinase substrate      -2             A
# OGDH Oxoglutarate dehydrogenase (lipoamide)             39             P
# MPZ Myelin protein zero (Charcot-Marie-Tooth ne...      29             P
# CBFA2 Core-binding factor, runt domain, alpha s...      19             P
# ...                                                    ...           ...
# FAS Del 2 mRNA                                          11             A
# mRNA encoding GPI-anchored protein p137                163             P
# MOG Myelin oligodendrocyte glycoprotein {altern...      10             A
# PXR1 Peroxisome receptor 1                              49             P
# SDC1 Syndecan 1                                        -12             A
# GCKR Glucokinase regulator                               7             A
# GCKR Glucokinase regulator                              30             P
# GCKR Glucokinase regulator                             -53             A
# MT-MMP protein                                         -26             A
# MMP2 Matrix metalloproteinase 2                        -28             A
# Protein tyrosine phosphatase                            25             A
# Sp17 gene                                               32             P
# mRNA (ocular albinism type 1 related)                    7             A
# BMPR-II                                                 26             A
# HISTONE H3.3                                           498             P
# Spermine synthase                                      160             P
# OBF-1 mRNA for octamer binding factor 1                  1             A
# RNA polymerase II subunit (hsRPB8) mRNA                282             P
# P2Y1 purinoceptor mRNA, long form                       -2             A
# Chemokine HCC-1                                          6             A
# Chemokine HCC-1                                         17             A
# Chemokine HCC-1                                        -10             A
# GUC1A2 Guanylate cyclase 1, soluble, alpha 2            -1             A
# NAD(P) transhydrogenase                                 41             P
# NAD(P) transhydrogenase                                 53             P
# Thimet oligopeptidase (metalloproteinase)               -5             A
# No cluster in current Unigene and no Genbank en...       4             A
# GCAP-II/uroguanylin precursor                           36             A
# BETA-DEFENSIN 1 PRECURSOR                               -3             A
# cre (spiked control)                                  3502             P
#
#                                                    call.13  Jurkat_0.5_hrs  \
# BioB (spiked control)                                   -5               A
# BioC (spiked control)                                    3               A
# BioD (spiked control)                                  192               P
# CYP3A3 Cytochrome P450 IIIA3 (nifedipine oxidas...      10               A
# CYP3A3 Cytochrome P450 IIIA3 (nifedipine oxidas...      12               M
# CYP3A3 Cytochrome P450 IIIA3 (nifedipine oxidas...      -3               A
# PRNP Prion protein (p27-30) (Creutzfeld-Jakob d...      19               P
# LTA Lymphotoxin alpha (formerly tumor necrosis ...       4               A
# ADH2 Alcohol dehydrogenase 2 (class I), beta po...       0               A
# CYP2C9 Cytochrome P450, subfamily IIC (mephenyt...       2               A
# CYC1 Cytochrome c-1                                    355               P
# ELASTASE IIIA PRECURSOR                                -14               A
# CYP3A7 Cytochrome P450 IIIA7 (P450-HFLa)                -5               A
# TYMS Thymidylate synthase                             1073               P
# FECH Ferrochelatase (protoporphyria)                   129               P
# T-CELL ANTIGEN CD7 PRECURSOR                           195               P
# PSMA3 Proteasome component C3                          274               P
# PSMA5 Proteasome component C5                          871               P
# PROTEASOME COMPONENT C8                               1025               P
# GAPD Glyceraldehyde-3-phosphate dehydrogenase          530               P
# PRPS1 Phosphoribosyl pyrophosphate synthetase s...     186               P
# FACL1 Long chain fatty acid acyl-coA ligase              1               A
# PTAFR Platelet activating factor receptor               -1               A
# POU1F1 POU domain, class 1, transcription facto...      -6               A
# ACAT1 Acetyl-Coenzyme A acetyltransferase 2 (ac...      73               P
# MACS Myristoylated alanine-rich C-kinase substrate       0               A
# MACS Myristoylated alanine-rich C-kinase substrate      -3               A
# OGDH Oxoglutarate dehydrogenase (lipoamide)             38               P
# MPZ Myelin protein zero (Charcot-Marie-Tooth ne...      22               P
# CBFA2 Core-binding factor, runt domain, alpha s...      20               P
# ...                                                    ...             ...
# FAS Del 2 mRNA                                          21               A
# mRNA encoding GPI-anchored protein p137                119               P
# MOG Myelin oligodendrocyte glycoprotein {altern...       5               A
# PXR1 Peroxisome receptor 1                              48               P
# SDC1 Syndecan 1                                         -7               A
# GCKR Glucokinase regulator                              29               A
# GCKR Glucokinase regulator                              57               P
# GCKR Glucokinase regulator                             -85               A
# MT-MMP protein                                         -31               A
# MMP2 Matrix metalloproteinase 2                        -16               A
# Protein tyrosine phosphatase                            86               A
# Sp17 gene                                               27               P
# mRNA (ocular albinism type 1 related)                   14               A
# BMPR-II                                                  4               A
# HISTONE H3.3                                           412               P
# Spermine synthase                                       68               P
# OBF-1 mRNA for octamer binding factor 1                  3               A
# RNA polymerase II subunit (hsRPB8) mRNA                217               P
# P2Y1 purinoceptor mRNA, long form                       -3               A
# Chemokine HCC-1                                          2               A
# Chemokine HCC-1                                         -3               A
# Chemokine HCC-1                                          4               A
# GUC1A2 Guanylate cyclase 1, soluble, alpha 2             6               A
# NAD(P) transhydrogenase                                 36               P
# NAD(P) transhydrogenase                                 57               P
# Thimet oligopeptidase (metalloproteinase)                1               A
# No cluster in current Unigene and no Genbank en...     -15               A
# GCAP-II/uroguanylin precursor                           15               A
# BETA-DEFENSIN 1 PRECURSOR                                6               A
# cre (spiked control)                                  3657               P
#
#                                                    call.14  Jurkat_4_hrs  \
# BioB (spiked control)                                   -2             A
# BioC (spiked control)                                    3             A
# BioD (spiked control)                                  190             P
# CYP3A3 Cytochrome P450 IIIA3 (nifedipine oxidas...       1             A
# CYP3A3 Cytochrome P450 IIIA3 (nifedipine oxidas...      12             A
# CYP3A3 Cytochrome P450 IIIA3 (nifedipine oxidas...      10             P
# PRNP Prion protein (p27-30) (Creutzfeld-Jakob d...      24             P
# LTA Lymphotoxin alpha (formerly tumor necrosis ...      -4             A
# ADH2 Alcohol dehydrogenase 2 (class I), beta po...       7             A
# CYP2C9 Cytochrome P450, subfamily IIC (mephenyt...      -1             A
# CYC1 Cytochrome c-1                                    234             P
# ELASTASE IIIA PRECURSOR                                  9             A
# CYP3A7 Cytochrome P450 IIIA7 (P450-HFLa)                -2             A
# TYMS Thymidylate synthase                             1027             P
# FECH Ferrochelatase (protoporphyria)                    92             P
# T-CELL ANTIGEN CD7 PRECURSOR                           182             P
# PSMA3 Proteasome component C3                          270             P
# PSMA5 Proteasome component C5                          777             P
# PROTEASOME COMPONENT C8                                984             P
# GAPD Glyceraldehyde-3-phosphate dehydrogenase          498             P
# PRPS1 Phosphoribosyl pyrophosphate synthetase s...     205             P
# FACL1 Long chain fatty acid acyl-coA ligase              8             A
# PTAFR Platelet activating factor receptor                5             A
# POU1F1 POU domain, class 1, transcription facto...      -1             A
# ACAT1 Acetyl-Coenzyme A acetyltransferase 2 (ac...     101             P
# MACS Myristoylated alanine-rich C-kinase substrate      -5             A
# MACS Myristoylated alanine-rich C-kinase substrate      -4             A
# OGDH Oxoglutarate dehydrogenase (lipoamide)             46             P
# MPZ Myelin protein zero (Charcot-Marie-Tooth ne...      30             P
# CBFA2 Core-binding factor, runt domain, alpha s...      16             P
# ...                                                    ...           ...
# FAS Del 2 mRNA                                          16             A
# mRNA encoding GPI-anchored protein p137                142             P
# MOG Myelin oligodendrocyte glycoprotein {altern...       2             A
# PXR1 Peroxisome receptor 1                              12             P
# SDC1 Syndecan 1                                         -5             A
# GCKR Glucokinase regulator                              15             P
# GCKR Glucokinase regulator                              26             P
# GCKR Glucokinase regulator                             -52             A
# MT-MMP protein                                         -26             A
# MMP2 Matrix metalloproteinase 2                        -34             A
# Protein tyrosine phosphatase                            37             A
# Sp17 gene                                               28             P
# mRNA (ocular albinism type 1 related)                    2             A
# BMPR-II                                                 24             P
# HISTONE H3.3                                           536             P
# Spermine synthase                                      162             P
# OBF-1 mRNA for octamer binding factor 1                 -1             A
# RNA polymerase II subunit (hsRPB8) mRNA                313             P
# P2Y1 purinoceptor mRNA, long form                        2             A
# Chemokine HCC-1                                         22             A
# Chemokine HCC-1                                          6             A
# Chemokine HCC-1                                          2             A
# GUC1A2 Guanylate cyclase 1, soluble, alpha 2             3             A
# NAD(P) transhydrogenase                                 26             P
# NAD(P) transhydrogenase                                 37             P
# Thimet oligopeptidase (metalloproteinase)               -4             A
# No cluster in current Unigene and no Genbank en...       9             A
# GCAP-II/uroguanylin precursor                           22             A
# BETA-DEFENSIN 1 PRECURSOR                                4             A
# cre (spiked control)                                  3321             P
#
#                                                    call.15  Jurkat_24_hrs call
# BioB (spiked control)                                   -3                   A
# BioC (spiked control)                                   -3                   A
# BioD (spiked control)                                  152                   P
# CYP3A3 Cytochrome P450 IIIA3 (nifedipine oxidas...       7                   A
# CYP3A3 Cytochrome P450 IIIA3 (nifedipine oxidas...      13                   M
# CYP3A3 Cytochrome P450 IIIA3 (nifedipine oxidas...      13                   A
# PRNP Prion protein (p27-30) (Creutzfeld-Jakob d...      21                   P
# LTA Lymphotoxin alpha (formerly tumor necrosis ...      11                   A
# ADH2 Alcohol dehydrogenase 2 (class I), beta po...      10                   A
# CYP2C9 Cytochrome P450, subfamily IIC (mephenyt...       3                   A
# CYC1 Cytochrome c-1                                    181                   P
# ELASTASE IIIA PRECURSOR                                 -9                   A
# CYP3A7 Cytochrome P450 IIIA7 (P450-HFLa)                -1                   A
# TYMS Thymidylate synthase                              967                   P
# FECH Ferrochelatase (protoporphyria)                    56                   P
# T-CELL ANTIGEN CD7 PRECURSOR                           108                   P
# PSMA3 Proteasome component C3                          271                   P
# PSMA5 Proteasome component C5                          951                   P
# PROTEASOME COMPONENT C8                                808                   P
# GAPD Glyceraldehyde-3-phosphate dehydrogenase          527                   P
# PRPS1 Phosphoribosyl pyrophosphate synthetase s...     132                   P
# FACL1 Long chain fatty acid acyl-coA ligase             10                   A
# PTAFR Platelet activating factor receptor               -2                   A
# POU1F1 POU domain, class 1, transcription facto...      -3                   A
# ACAT1 Acetyl-Coenzyme A acetyltransferase 2 (ac...      56                   P
# MACS Myristoylated alanine-rich C-kinase substrate      -1                   A
# MACS Myristoylated alanine-rich C-kinase substrate       4                   A
# OGDH Oxoglutarate dehydrogenase (lipoamide)             39                   P
# MPZ Myelin protein zero (Charcot-Marie-Tooth ne...      35                   P
# CBFA2 Core-binding factor, runt domain, alpha s...       9                   A
# ...                                                    ...                 ...
# FAS Del 2 mRNA                                          19                   P
# mRNA encoding GPI-anchored protein p137                115                   P
# MOG Myelin oligodendrocyte glycoprotein {altern...      -1                   A
# PXR1 Peroxisome receptor 1                               9                   A
# SDC1 Syndecan 1                                        -18                   A
# GCKR Glucokinase regulator                              20                   P
# GCKR Glucokinase regulator                              28                   P
# GCKR Glucokinase regulator                             -62                   A
# MT-MMP protein                                         -16                   A
# MMP2 Matrix metalloproteinase 2                        -26                   A
# Protein tyrosine phosphatase                            59                   A
# Sp17 gene                                               42                   P
# mRNA (ocular albinism type 1 related)                    2                   A
# BMPR-II                                                 25                   P
# HISTONE H3.3                                           582                   P
# Spermine synthase                                      259                   P
# OBF-1 mRNA for octamer binding factor 1                  3                   A
# RNA polymerase II subunit (hsRPB8) mRNA                226                   P
# P2Y1 purinoceptor mRNA, long form                       -1                   A
# Chemokine HCC-1                                         23                   A
# Chemokine HCC-1                                         14                   A
# Chemokine HCC-1                                         21                   A
# GUC1A2 Guanylate cyclase 1, soluble, alpha 2            -2                   A
# NAD(P) transhydrogenase                                 27                   P
# NAD(P) transhydrogenase                                 34                   P
# Thimet oligopeptidase (metalloproteinase)                0                   A
# No cluster in current Unigene and no Genbank en...       3                   A
# GCAP-II/uroguanylin precursor                           21                   A
# BETA-DEFENSIN 1 PRECURSOR                               -7                   A
# cre (spiked control)                                  3223                   P
#
# [7229 rows x 35 columns]

# %%
# A. How many distinct Gene Accession Numbers are represented in the data set?
len(set(uarray["Gene Accession Number"]))
# Out:
# 757

# %%
import numpy as np
set(uarray["HL60_0_hrs"]) # unique values for single column
cat_cols = uarray.columns[2:-1:2] # categorical columns
uarray[cat_cols] # matrix of categorical columns
uarray[cat_cols].values
uarray_cats = np.unique(uarray[cat_cols])  # unique values in all catigorical columns
uarray_cats
amp_map = {x:ord(x) for x in uarray_cats} # dict comp FTW!
amp_map
# Out:
# {'A': 65, 'M': 77, 'P': 80}

# %%
uarray[:][:2]
# Out:
#                       Gene Description  Gene Accession Number HL60_0_hrs  \
# BioB (spiked control)             BioB                      7          A
# BioC (spiked control)             BioC                     62          P
#
#                        call HL60_0.5_hrs  call.1 HL60_4_hrs  call.2  \
# BioB (spiked control)   -12            A       3          A      19
# BioC (spiked control)     5            A      75          P     107
#
#                       HL60_24_hrs  call.3         ...         call.11  \
# BioB (spiked control)           A     254         ...              -7
# BioC (spiked control)           P     596         ...               2
#
#                        NB4_72_hrs call.12  Jurkat_0_hrs call.13  \
# BioB (spiked control)           A      -5             A      -5
# BioC (spiked control)           A       1             A       3
#
#                        Jurkat_0.5_hrs call.14  Jurkat_4_hrs call.15  \
# BioB (spiked control)               A      -2             A      -3
# BioC (spiked control)               A       3             A      -3
#
#                        Jurkat_24_hrs call
# BioB (spiked control)                   A
# BioC (spiked control)                   A
#
# [2 rows x 35 columns]

# %%
len(uarray_cats)
# Out:
# 3

# %%
# B. Which two time points are the most highly correlated for each cell type? 
# http://www.slideshare.net/jaidevdeshpande/categorical-data-analysis-in-python
# http://fastml.com/converting-categorical-data-into-numbers-with-pandas-and-scikit-learn/
# http://nbviewer.jupyter.org/github/esafak/mca/blob/master/docs/mca-BurgundiesExample.ipynb

import random
from scipy.stats import kendalltau

cat_df = uarray[ cols_to_retain ][:10]
x = list(cat_df["HL60_0_hrs"].values)
y = list(cat_df["HL60_0.5_hrs"].values)

r = x[:]; random.shuffle(r) # confirm that order *does* matter

kendalltau(x, y), kendalltau(r, y)
# Out:
# (KendalltauResult(correlation=0.21821789023599239, pvalue=0.3797754875191558),
#  KendalltauResult(correlation=-0.3273268353539886, pvalue=0.18768278427580298))

# %%
starts = range(17)[::4]
ends = range(17)[4::4]
zip(starts,ends)
# Out:
# [(0, 4), (4, 8), (8, 12), (12, 16)]

# %%
from collections import Counter
cell_lines = [x.split("_")[0] for x in cat_cols] # Assumes that Cell Line + time is _ delimited
cell_lines
colcnts = Counter()
for cell_line in cell_lines:
    colcnts[cell_line] += 1
colcnts
# Out:
# Counter({'HL60': 4, 'Jurkat': 3, 'NB4': 5, 'U937': 4})

# %%
"HL60" in cat_cols
[cat_col for cat_col in cat_cols if "HL60" in cat_col]
# Out:
# ['HL60_0_hrs', 'HL60_0.5_hrs', 'HL60_4_hrs', 'HL60_24_hrs']

# %%
from collections import namedtuple
Point = namedtuple('Point', 'x y')

composite_key = namedtuple("composite_key", "cell_line time units")
Assay = namedtuple("Assay", "composite_key AssayTime")

# %%
# Data Structure for results # ToDo: 1. convert to namedtuple 2. convert to class
Assay = {}
for cell_line in colcnts:
    Assay[cell_line] = {}
    Assay[cell_line]["colcnt"] = colcnts[cell_line] 
print Assay
# Out:
# {'U937': {'colcnt': 4}, 'HL60': {'colcnt': 4}, 'NB4': {'colcnt': 5}, 'Jurkat': {'colcnt': 3}}

# %%
import pprint
import itertools
Assay = {}
for cell_line in colcnts:
    Assay[cell_line] = {}
    Assay[cell_line]["colcnt"] = colcnts[cell_line] 
    
for cell_line in Assay.keys():
    print "Generating stats for cell_line {0}".format(cell_line)
    # search for col name containing the cell line name 
    # e.g.  ('U937_0_hrs', 'U937_0.5_hrs') are both in cell line 'U937'
    cell_line_cols = [cat_col for cat_col in cat_cols if cell_line in cat_col]
    # get all A:B combinations of the times. e.g. XYZ: XY,YZ,XZ
    combos = itertools.combinations(cell_line_cols, 2) 
    Assay[cell_line]["time_stats"] = []
    for combo in combos:
        combo_key = (combo[0].split("_")[2], tuple(sorted([x.split("_")[1] for x in combo])))
        kt = kendalltau(list(uarray[combo[0]].values), list(uarray[combo[1]].values)), # stats FTW!
        ndiff = sum(uarray[combo[0]] != uarray[combo[1]]) # n differences
        Assay[cell_line]["time_stats"].append({combo_key: {"kt": kt, 
                                                           "ndiff": ndiff}})                                   
pprint.pprint(Assay)
# Out:
# Generating stats for cell_line U937
# Generating stats for cell_line HL60
# Generating stats for cell_line NB4
# Generating stats for cell_line Jurkat
# {'HL60': {'colcnt': 4,
#           'time_stats': [{('hrs', ('0', '0.5')): {'kt': (KendalltauResult(correlation=0.72212092513230175, pvalue=0.0),),
#                                                   'ndiff': 1070}},
#                          {('hrs', ('0', '4')): {'kt': (KendalltauResult(correlation=0.74546491226697265, pvalue=0.0),),
#                                                 'ndiff': 970}},
#                          {('hrs', ('0', '24')): {'kt': (KendalltauResult(correlation=0.63221288349208249, pvalue=0.0),),
#                                                  'ndiff': 1373}},
#                          {('hrs', ('0.5', '4')): {'kt': (KendalltauResult(correlation=0.72339450166114305, pvalue=0.0),),
#                                                   'ndiff': 1069}},
#                          {('hrs', ('0.5', '24')): {'kt': (KendalltauResult(correlation=0.64851678846817296, pvalue=0.0),),
#                                                    'ndiff': 1341}},
#                          {('hrs', ('24', '4')): {'kt': (KendalltauResult(correlation=0.6523475060395485, pvalue=0.0),),
#                                                  'ndiff': 1307}}]},
#  'Jurkat': {'colcnt': 3,
#             'time_stats': [{('hrs', ('0', '0.5')): {'kt': (KendalltauResult(correlation=0.73825874038758454, pvalue=0.0),),
#                                                     'ndiff': 1013}},
#                            {('hrs', ('0', '4')): {'kt': (KendalltauResult(correlation=0.75991856230190957, pvalue=0.0),),
#                                                   'ndiff': 934}},
#                            {('hrs', ('0.5', '4')): {'kt': (KendalltauResult(correlation=0.77261542380079185, pvalue=0.0),),
#                                                     'ndiff': 880}}]},
#  'NB4': {'colcnt': 5,
#          'time_stats': [{('hrs', ('0', '5.5')): {'kt': (KendalltauResult(correlation=0.72533576938300282, pvalue=0.0),),
#                                                  'ndiff': 963}},
#                         {('hrs', ('0', '24')): {'kt': (KendalltauResult(correlation=0.67202760763065272, pvalue=0.0),),
#                                                 'ndiff': 1151}},
#                         {('hrs', ('0', '48')): {'kt': (KendalltauResult(correlation=0.6800010477874614, pvalue=0.0),),
#                                                 'ndiff': 1143}},
#                         {('hrs', ('0', '72')): {'kt': (KendalltauResult(correlation=0.66098559792005684, pvalue=0.0),),
#                                                 'ndiff': 1233}},
#                         {('hrs', ('24', '5.5')): {'kt': (KendalltauResult(correlation=0.74178722940377351, pvalue=0.0),),
#                                                   'ndiff': 920}},
#                         {('hrs', ('48', '5.5')): {'kt': (KendalltauResult(correlation=0.71828091430430929, pvalue=0.0),),
#                                                   'ndiff': 1010}},
#                         {('hrs', ('5.5', '72')): {'kt': (KendalltauResult(correlation=0.69698281810922313, pvalue=0.0),),
#                                                   'ndiff': 1105}},
#                         {('hrs', ('24', '48')): {'kt': (KendalltauResult(correlation=0.76020482034346049, pvalue=0.0),),
#                                                  'ndiff': 889}},
#                         {('hrs', ('24', '72')): {'kt': (KendalltauResult(correlation=0.74842059387416682, pvalue=0.0),),
#                                                  'ndiff': 935}},
#                         {('hrs', ('48', '72')): {'kt': (KendalltauResult(correlation=0.78120719065888022, pvalue=0.0),),
#                                                  'ndiff': 838}}]},
#  'U937': {'colcnt': 4,
#           'time_stats': [{('hrs', ('0', '0.5')): {'kt': (KendalltauResult(correlation=0.78549422727048213, pvalue=0.0),),
#                                                   'ndiff': 720}},
#                          {('hrs', ('0', '4')): {'kt': (KendalltauResult(correlation=0.7825222786571604, pvalue=0.0),),
#                                                 'ndiff': 736}},
#                          {('hrs', ('0', '24')): {'kt': (KendalltauResult(correlation=0.6891455485006357, pvalue=0.0),),
#                                                  'ndiff': 1051}},
#                          {('hrs', ('0.5', '4')): {'kt': (KendalltauResult(correlation=0.8085087904928715, pvalue=0.0),),
#                                                   'ndiff': 666}},
#                          {('hrs', ('0.5', '24')): {'kt': (KendalltauResult(correlation=0.71063872805438144, pvalue=0.0),),
#                                                    'ndiff': 998}},
#                          {('hrs', ('24', '4')): {'kt': (KendalltauResult(correlation=0.69818741344825597, pvalue=0.0),),
#                                                  'ndiff': 1055}}]}}

# %%
import itertools

#cells = [(0,4),(4,9)] # (start idx, end idx) columns for each cell type
#cells = zip(starts,ends)

for cell in cells:
    start = cell[0]; end = cell[1]
    print start, end
    combos = itertools.combinations(cat_cols[start:end], 2) # FixMe: nTimesteps & start:end for cell line

    for combo in combos:
        print (combo, # time compare
           #kendalltau(list(uarray[combo[0]].values), list(uarray[combo[1]].values)), # stats FTW!
           #sum(uarray[combo[0]] != uarray[combo[1]]) # n differences
          )
# Out:
# 0 4
# (('HL60_0_hrs', 'HL60_0.5_hrs'),)
# (('HL60_0_hrs', 'HL60_4_hrs'),)
# (('HL60_0_hrs', 'HL60_24_hrs'),)
# (('HL60_0.5_hrs', 'HL60_4_hrs'),)
# (('HL60_0.5_hrs', 'HL60_24_hrs'),)
# (('HL60_4_hrs', 'HL60_24_hrs'),)
# 4 8
# (('U937_0_hrs', 'U937_0.5_hrs'),)
# (('U937_0_hrs', 'U937_4_hrs'),)
# (('U937_0_hrs', 'U937_24_hrs'),)
# (('U937_0.5_hrs', 'U937_4_hrs'),)
# (('U937_0.5_hrs', 'U937_24_hrs'),)
# (('U937_4_hrs', 'U937_24_hrs'),)
# 8 12
# (('NB4_0_hrs', 'NB4_5.5_hrs'),)
# (('NB4_0_hrs', 'NB4_24_hrs'),)
# (('NB4_0_hrs', 'NB4_48_hrs'),)
# (('NB4_5.5_hrs', 'NB4_24_hrs'),)
# (('NB4_5.5_hrs', 'NB4_48_hrs'),)
# (('NB4_24_hrs', 'NB4_48_hrs'),)
# 12 16
# (('NB4_72_hrs', 'Jurkat_0_hrs'),)
# (('NB4_72_hrs', 'Jurkat_0.5_hrs'),)
# (('NB4_72_hrs', 'Jurkat_4_hrs'),)
# (('Jurkat_0_hrs', 'Jurkat_0.5_hrs'),)
# (('Jurkat_0_hrs', 'Jurkat_4_hrs'),)
# (('Jurkat_0.5_hrs', 'Jurkat_4_hrs'),)

# %%
# Out:
# <mca.mca instance at 0x115628560>

# %%
uarray.apply(pandas.to_numeric, args=('coerce',))
# Out:
#                                                     Gene Description  \
# BioB (spiked control)                                            NaN
# BioC (spiked control)                                            NaN
# BioD (spiked control)                                            NaN
# CYP3A3 Cytochrome P450 IIIA3 (nifedipine oxidas...               NaN
# CYP3A3 Cytochrome P450 IIIA3 (nifedipine oxidas...               NaN
# CYP3A3 Cytochrome P450 IIIA3 (nifedipine oxidas...               NaN
# PRNP Prion protein (p27-30) (Creutzfeld-Jakob d...               NaN
# LTA Lymphotoxin alpha (formerly tumor necrosis ...               NaN
# ADH2 Alcohol dehydrogenase 2 (class I), beta po...               NaN
# CYP2C9 Cytochrome P450, subfamily IIC (mephenyt...               NaN
# CYC1 Cytochrome c-1                                              NaN
# ELASTASE IIIA PRECURSOR                                          NaN
# CYP3A7 Cytochrome P450 IIIA7 (P450-HFLa)                         NaN
# TYMS Thymidylate synthase                                        NaN
# FECH Ferrochelatase (protoporphyria)                             NaN
# T-CELL ANTIGEN CD7 PRECURSOR                                     NaN
# PSMA3 Proteasome component C3                                    NaN
# PSMA5 Proteasome component C5                                    NaN
# PROTEASOME COMPONENT C8                                          NaN
# GAPD Glyceraldehyde-3-phosphate dehydrogenase                    NaN
# PRPS1 Phosphoribosyl pyrophosphate synthetase s...               NaN
# FACL1 Long chain fatty acid acyl-coA ligase                      NaN
# PTAFR Platelet activating factor receptor                        NaN
# POU1F1 POU domain, class 1, transcription facto...               NaN
# ACAT1 Acetyl-Coenzyme A acetyltransferase 2 (ac...               NaN
# MACS Myristoylated alanine-rich C-kinase substrate               NaN
# MACS Myristoylated alanine-rich C-kinase substrate               NaN
# OGDH Oxoglutarate dehydrogenase (lipoamide)                      NaN
# MPZ Myelin protein zero (Charcot-Marie-Tooth ne...               NaN
# CBFA2 Core-binding factor, runt domain, alpha s...               NaN
# ...                                                              ...
# FAS Del 2 mRNA                                                   NaN
# mRNA encoding GPI-anchored protein p137                          NaN
# MOG Myelin oligodendrocyte glycoprotein {altern...               NaN
# PXR1 Peroxisome receptor 1                                       NaN
# SDC1 Syndecan 1                                                  NaN
# GCKR Glucokinase regulator                                       NaN
# GCKR Glucokinase regulator                                       NaN
# GCKR Glucokinase regulator                                       NaN
# MT-MMP protein                                                   NaN
# MMP2 Matrix metalloproteinase 2                                  NaN
# Protein tyrosine phosphatase                                     NaN
# Sp17 gene                                                        NaN
# mRNA (ocular albinism type 1 related)                            NaN
# BMPR-II                                                          NaN
# HISTONE H3.3                                                     NaN
# Spermine synthase                                                NaN
# OBF-1 mRNA for octamer binding factor 1                          NaN
# RNA polymerase II subunit (hsRPB8) mRNA                          NaN
# P2Y1 purinoceptor mRNA, long form                                NaN
# Chemokine HCC-1                                                  NaN
# Chemokine HCC-1                                                  NaN
# Chemokine HCC-1                                                  NaN
# GUC1A2 Guanylate cyclase 1, soluble, alpha 2                     NaN
# NAD(P) transhydrogenase                                          NaN
# NAD(P) transhydrogenase                                          NaN
# Thimet oligopeptidase (metalloproteinase)                        NaN
# No cluster in current Unigene and no Genbank en...               NaN
# GCAP-II/uroguanylin precursor                                    NaN
# BETA-DEFENSIN 1 PRECURSOR                                        NaN
# cre (spiked control)                                             NaN
#
#                                                     Gene Accession Number  \
# BioB (spiked control)                                                   7
# BioC (spiked control)                                                  62
# BioD (spiked control)                                                 372
# CYP3A3 Cytochrome P450 IIIA3 (nifedipine oxidas...                      8
# CYP3A3 Cytochrome P450 IIIA3 (nifedipine oxidas...                     -7
# CYP3A3 Cytochrome P450 IIIA3 (nifedipine oxidas...                      5
# PRNP Prion protein (p27-30) (Creutzfeld-Jakob d...                     13
# LTA Lymphotoxin alpha (formerly tumor necrosis ...                      5
# ADH2 Alcohol dehydrogenase 2 (class I), beta po...                      7
# CYP2C9 Cytochrome P450, subfamily IIC (mephenyt...                      4
# CYC1 Cytochrome c-1                                                   411
# ELASTASE IIIA PRECURSOR                                                 1
# CYP3A7 Cytochrome P450 IIIA7 (P450-HFLa)                                3
# TYMS Thymidylate synthase                                             165
# FECH Ferrochelatase (protoporphyria)                                   54
# T-CELL ANTIGEN CD7 PRECURSOR                                           37
# PSMA3 Proteasome component C3                                         105
# PSMA5 Proteasome component C5                                        1266
# PROTEASOME COMPONENT C8                                               889
# GAPD Glyceraldehyde-3-phosphate dehydrogenase                         533
# PRPS1 Phosphoribosyl pyrophosphate synthetase s...                     76
# FACL1 Long chain fatty acid acyl-coA ligase                            50
# PTAFR Platelet activating factor receptor                               9
# POU1F1 POU domain, class 1, transcription facto...                     -5
# ACAT1 Acetyl-Coenzyme A acetyltransferase 2 (ac...                    139
# MACS Myristoylated alanine-rich C-kinase substrate                     -3
# MACS Myristoylated alanine-rich C-kinase substrate                     -1
# OGDH Oxoglutarate dehydrogenase (lipoamide)                            66
# MPZ Myelin protein zero (Charcot-Marie-Tooth ne...                      9
# CBFA2 Core-binding factor, runt domain, alpha s...                    -10
# ...                                                                   ...
# FAS Del 2 mRNA                                                         -1
# mRNA encoding GPI-anchored protein p137                               197
# MOG Myelin oligodendrocyte glycoprotein {altern...                      2
# PXR1 Peroxisome receptor 1                                             29
# SDC1 Syndecan 1                                                       -19
# GCKR Glucokinase regulator                                             17
# GCKR Glucokinase regulator                                             31
# GCKR Glucokinase regulator                                            -72
# MT-MMP protein                                                        -34
# MMP2 Matrix metalloproteinase 2                                       -35
# Protein tyrosine phosphatase                                           24
# Sp17 gene                                                              11
# mRNA (ocular albinism type 1 related)                                   7
# BMPR-II                                                                24
# HISTONE H3.3                                                          335
# Spermine synthase                                                      83
# OBF-1 mRNA for octamer binding factor 1                                 5
# RNA polymerase II subunit (hsRPB8) mRNA                               132
# P2Y1 purinoceptor mRNA, long form                                       9
# Chemokine HCC-1                                                        14
# Chemokine HCC-1                                                        -9
# Chemokine HCC-1                                                        22
# GUC1A2 Guanylate cyclase 1, soluble, alpha 2                           -2
# NAD(P) transhydrogenase                                                37
# NAD(P) transhydrogenase                                                93
# Thimet oligopeptidase (metalloproteinase)                             -11
# No cluster in current Unigene and no Genbank en...                    -10
# GCAP-II/uroguanylin precursor                                          13
# BETA-DEFENSIN 1 PRECURSOR                                              -5
# cre (spiked control)                                                  871
#
#                                                     HL60_0_hrs  call  \
# BioB (spiked control)                                      NaN   -12
# BioC (spiked control)                                      NaN     5
# BioD (spiked control)                                      NaN   143
# CYP3A3 Cytochrome P450 IIIA3 (nifedipine oxidas...         NaN    28
# CYP3A3 Cytochrome P450 IIIA3 (nifedipine oxidas...         NaN    36
# CYP3A3 Cytochrome P450 IIIA3 (nifedipine oxidas...         NaN    -8
# PRNP Prion protein (p27-30) (Creutzfeld-Jakob d...         NaN     8
# LTA Lymphotoxin alpha (formerly tumor necrosis ...         NaN   -12
# ADH2 Alcohol dehydrogenase 2 (class I), beta po...         NaN    -1
# CYP2C9 Cytochrome P450, subfamily IIC (mephenyt...         NaN    14
# CYC1 Cytochrome c-1                                        NaN   413
# ELASTASE IIIA PRECURSOR                                    NaN   -11
# CYP3A7 Cytochrome P450 IIIA7 (P450-HFLa)                   NaN    -2
# TYMS Thymidylate synthase                                  NaN   273
# FECH Ferrochelatase (protoporphyria)                       NaN    82
# T-CELL ANTIGEN CD7 PRECURSOR                               NaN    15
# PSMA3 Proteasome component C3                              NaN   118
# PSMA5 Proteasome component C5                              NaN  1305
# PROTEASOME COMPONENT C8                                    NaN   824
# GAPD Glyceraldehyde-3-phosphate dehydrogenase              NaN   554
# PRPS1 Phosphoribosyl pyrophosphate synthetase s...         NaN    92
# FACL1 Long chain fatty acid acyl-coA ligase                NaN    57
# PTAFR Platelet activating factor receptor                  NaN     6
# POU1F1 POU domain, class 1, transcription facto...         NaN     1
# ACAT1 Acetyl-Coenzyme A acetyltransferase 2 (ac...         NaN   212
# MACS Myristoylated alanine-rich C-kinase substrate         NaN     1
# MACS Myristoylated alanine-rich C-kinase substrate         NaN     1
# OGDH Oxoglutarate dehydrogenase (lipoamide)                NaN   106
# MPZ Myelin protein zero (Charcot-Marie-Tooth ne...         NaN    24
# CBFA2 Core-binding factor, runt domain, alpha s...         NaN    -2
# ...                                                        ...   ...
# FAS Del 2 mRNA                                             NaN     5
# mRNA encoding GPI-anchored protein p137                    NaN   147
# MOG Myelin oligodendrocyte glycoprotein {altern...         NaN    10
# PXR1 Peroxisome receptor 1                                 NaN   -17
# SDC1 Syndecan 1                                            NaN   -17
# GCKR Glucokinase regulator                                 NaN    48
# GCKR Glucokinase regulator                                 NaN    60
# GCKR Glucokinase regulator                                 NaN  -245
# MT-MMP protein                                             NaN   -19
# MMP2 Matrix metalloproteinase 2                            NaN    15
# Protein tyrosine phosphatase                               NaN    72
# Sp17 gene                                                  NaN     4
# mRNA (ocular albinism type 1 related)                      NaN     4
# BMPR-II                                                    NaN    17
# HISTONE H3.3                                               NaN   384
# Spermine synthase                                          NaN    60
# OBF-1 mRNA for octamer binding factor 1                    NaN     1
# RNA polymerase II subunit (hsRPB8) mRNA                    NaN   256
# P2Y1 purinoceptor mRNA, long form                          NaN    20
# Chemokine HCC-1                                            NaN    37
# Chemokine HCC-1                                            NaN    18
# Chemokine HCC-1                                            NaN    -3
# GUC1A2 Guanylate cyclase 1, soluble, alpha 2               NaN     3
# NAD(P) transhydrogenase                                    NaN    39
# NAD(P) transhydrogenase                                    NaN    56
# Thimet oligopeptidase (metalloproteinase)                  NaN   -31
# No cluster in current Unigene and no Genbank en...         NaN    -6
# GCAP-II/uroguanylin precursor                              NaN     4
# BETA-DEFENSIN 1 PRECURSOR                                  NaN    -5
# cre (spiked control)                                       NaN   296
#
#                                                     HL60_0.5_hrs  call.1  \
# BioB (spiked control)                                        NaN       3
# BioC (spiked control)                                        NaN      75
# BioD (spiked control)                                        NaN     405
# CYP3A3 Cytochrome P450 IIIA3 (nifedipine oxidas...           NaN       8
# CYP3A3 Cytochrome P450 IIIA3 (nifedipine oxidas...           NaN       5
# CYP3A3 Cytochrome P450 IIIA3 (nifedipine oxidas...           NaN       4
# PRNP Prion protein (p27-30) (Creutzfeld-Jakob d...           NaN      24
# LTA Lymphotoxin alpha (formerly tumor necrosis ...           NaN      -8
# ADH2 Alcohol dehydrogenase 2 (class I), beta po...           NaN       3
# CYP2C9 Cytochrome P450, subfamily IIC (mephenyt...           NaN       0
# CYC1 Cytochrome c-1                                          NaN     468
# ELASTASE IIIA PRECURSOR                                      NaN       3
# CYP3A7 Cytochrome P450 IIIA7 (P450-HFLa)                     NaN      11
# TYMS Thymidylate synthase                                    NaN     260
# FECH Ferrochelatase (protoporphyria)                         NaN      52
# T-CELL ANTIGEN CD7 PRECURSOR                                 NaN       7
# PSMA3 Proteasome component C3                                NaN     132
# PSMA5 Proteasome component C5                                NaN    1277
# PROTEASOME COMPONENT C8                                      NaN     652
# GAPD Glyceraldehyde-3-phosphate dehydrogenase                NaN     589
# PRPS1 Phosphoribosyl pyrophosphate synthetase s...           NaN      69
# FACL1 Long chain fatty acid acyl-coA ligase                  NaN     122
# PTAFR Platelet activating factor receptor                    NaN       7
# POU1F1 POU domain, class 1, transcription facto...           NaN       3
# ACAT1 Acetyl-Coenzyme A acetyltransferase 2 (ac...           NaN     187
# MACS Myristoylated alanine-rich C-kinase substrate           NaN       5
# MACS Myristoylated alanine-rich C-kinase substrate           NaN       2
# OGDH Oxoglutarate dehydrogenase (lipoamide)                  NaN      60
# MPZ Myelin protein zero (Charcot-Marie-Tooth ne...           NaN      30
# CBFA2 Core-binding factor, runt domain, alpha s...           NaN       0
# ...                                                          ...     ...
# FAS Del 2 mRNA                                               NaN      -2
# mRNA encoding GPI-anchored protein p137                      NaN     304
# MOG Myelin oligodendrocyte glycoprotein {altern...           NaN       9
# PXR1 Peroxisome receptor 1                                   NaN      10
# SDC1 Syndecan 1                                              NaN     -16
# GCKR Glucokinase regulator                                   NaN      31
# GCKR Glucokinase regulator                                   NaN      67
# GCKR Glucokinase regulator                                   NaN    -149
# MT-MMP protein                                               NaN     -17
# MMP2 Matrix metalloproteinase 2                              NaN       1
# Protein tyrosine phosphatase                                 NaN      86
# Sp17 gene                                                    NaN      12
# mRNA (ocular albinism type 1 related)                        NaN       1
# BMPR-II                                                      NaN      18
# HISTONE H3.3                                                 NaN     485
# Spermine synthase                                            NaN      76
# OBF-1 mRNA for octamer binding factor 1                      NaN      -4
# RNA polymerase II subunit (hsRPB8) mRNA                      NaN     252
# P2Y1 purinoceptor mRNA, long form                            NaN       3
# Chemokine HCC-1                                              NaN       3
# Chemokine HCC-1                                              NaN      17
# Chemokine HCC-1                                              NaN      55
# GUC1A2 Guanylate cyclase 1, soluble, alpha 2                 NaN       5
# NAD(P) transhydrogenase                                      NaN     -36
# NAD(P) transhydrogenase                                      NaN       6
# Thimet oligopeptidase (metalloproteinase)                    NaN     -22
# No cluster in current Unigene and no Genbank en...           NaN      18
# GCAP-II/uroguanylin precursor                                NaN       2
# BETA-DEFENSIN 1 PRECURSOR                                    NaN       1
# cre (spiked control)                                         NaN    1004
#
#                                                     HL60_4_hrs  call.2  \
# BioB (spiked control)                                      NaN      19
# BioC (spiked control)                                      NaN     107
# BioD (spiked control)                                      NaN     551
# CYP3A3 Cytochrome P450 IIIA3 (nifedipine oxidas...         NaN      27
# CYP3A3 Cytochrome P450 IIIA3 (nifedipine oxidas...         NaN      41
# CYP3A3 Cytochrome P450 IIIA3 (nifedipine oxidas...         NaN       1
# PRNP Prion protein (p27-30) (Creutzfeld-Jakob d...         NaN      44
# LTA Lymphotoxin alpha (formerly tumor necrosis ...         NaN      -6
# ADH2 Alcohol dehydrogenase 2 (class I), beta po...         NaN       3
# CYP2C9 Cytochrome P450, subfamily IIC (mephenyt...         NaN      -2
# CYC1 Cytochrome c-1                                        NaN     136
# ELASTASE IIIA PRECURSOR                                    NaN      13
# CYP3A7 Cytochrome P450 IIIA7 (P450-HFLa)                   NaN      10
# TYMS Thymidylate synthase                                  NaN      35
# FECH Ferrochelatase (protoporphyria)                       NaN      22
# T-CELL ANTIGEN CD7 PRECURSOR                               NaN      16
# PSMA3 Proteasome component C3                              NaN     159
# PSMA5 Proteasome component C5                              NaN     820
# PROTEASOME COMPONENT C8                                    NaN     364
# GAPD Glyceraldehyde-3-phosphate dehydrogenase              NaN     272
# PRPS1 Phosphoribosyl pyrophosphate synthetase s...         NaN      25
# FACL1 Long chain fatty acid acyl-coA ligase                NaN      51
# PTAFR Platelet activating factor receptor                  NaN       6
# POU1F1 POU domain, class 1, transcription facto...         NaN     -15
# ACAT1 Acetyl-Coenzyme A acetyltransferase 2 (ac...         NaN      12
# MACS Myristoylated alanine-rich C-kinase substrate         NaN       0
# MACS Myristoylated alanine-rich C-kinase substrate         NaN       0
# OGDH Oxoglutarate dehydrogenase (lipoamide)                NaN      84
# MPZ Myelin protein zero (Charcot-Marie-Tooth ne...         NaN      30
# CBFA2 Core-binding factor, runt domain, alpha s...         NaN     -12
# ...                                                        ...     ...
# FAS Del 2 mRNA                                             NaN       7
# mRNA encoding GPI-anchored protein p137                    NaN     117
# MOG Myelin oligodendrocyte glycoprotein {altern...         NaN      17
# PXR1 Peroxisome receptor 1                                 NaN      30
# SDC1 Syndecan 1                                            NaN      -1
# GCKR Glucokinase regulator                                 NaN      30
# GCKR Glucokinase regulator                                 NaN      56
# GCKR Glucokinase regulator                                 NaN    -174
# MT-MMP protein                                             NaN     323
# MMP2 Matrix metalloproteinase 2                            NaN     -51
# Protein tyrosine phosphatase                               NaN      86
# Sp17 gene                                                  NaN      30
# mRNA (ocular albinism type 1 related)                      NaN       0
# BMPR-II                                                    NaN      -4
# HISTONE H3.3                                               NaN     339
# Spermine synthase                                          NaN     107
# OBF-1 mRNA for octamer binding factor 1                    NaN       1
# RNA polymerase II subunit (hsRPB8) mRNA                    NaN     105
# P2Y1 purinoceptor mRNA, long form                          NaN      13
# Chemokine HCC-1                                            NaN      14
# Chemokine HCC-1                                            NaN      37
# Chemokine HCC-1                                            NaN     -42
# GUC1A2 Guanylate cyclase 1, soluble, alpha 2               NaN      -1
# NAD(P) transhydrogenase                                    NaN      20
# NAD(P) transhydrogenase                                    NaN      87
# Thimet oligopeptidase (metalloproteinase)                  NaN     -19
# No cluster in current Unigene and no Genbank en...         NaN      40
# GCAP-II/uroguanylin precursor                              NaN       6
# BETA-DEFENSIN 1 PRECURSOR                                  NaN      -8
# cre (spiked control)                                       NaN    1380
#
#                                                     HL60_24_hrs  call.3  \
# BioB (spiked control)                                       NaN     254
# BioC (spiked control)                                       NaN     596
# BioD (spiked control)                                       NaN     752
# CYP3A3 Cytochrome P450 IIIA3 (nifedipine oxidas...          NaN       6
# CYP3A3 Cytochrome P450 IIIA3 (nifedipine oxidas...          NaN       2
# CYP3A3 Cytochrome P450 IIIA3 (nifedipine oxidas...          NaN      -5
# PRNP Prion protein (p27-30) (Creutzfeld-Jakob d...          NaN      32
# LTA Lymphotoxin alpha (formerly tumor necrosis ...          NaN       7
# ADH2 Alcohol dehydrogenase 2 (class I), beta po...          NaN       1
# CYP2C9 Cytochrome P450, subfamily IIC (mephenyt...          NaN      -1
# CYC1 Cytochrome c-1                                         NaN     322
# ELASTASE IIIA PRECURSOR                                     NaN     -21
# CYP3A7 Cytochrome P450 IIIA7 (P450-HFLa)                    NaN      -3
# TYMS Thymidylate synthase                                   NaN     808
# FECH Ferrochelatase (protoporphyria)                        NaN      13
# T-CELL ANTIGEN CD7 PRECURSOR                                NaN      13
# PSMA3 Proteasome component C3                               NaN     136
# PSMA5 Proteasome component C5                               NaN     635
# PROTEASOME COMPONENT C8                                     NaN     476
# GAPD Glyceraldehyde-3-phosphate dehydrogenase               NaN     366
# PRPS1 Phosphoribosyl pyrophosphate synthetase s...          NaN      61
# FACL1 Long chain fatty acid acyl-coA ligase                 NaN      29
# PTAFR Platelet activating factor receptor                   NaN       2
# POU1F1 POU domain, class 1, transcription facto...          NaN       1
# ACAT1 Acetyl-Coenzyme A acetyltransferase 2 (ac...          NaN     130
# MACS Myristoylated alanine-rich C-kinase substrate          NaN      57
# MACS Myristoylated alanine-rich C-kinase substrate          NaN      38
# OGDH Oxoglutarate dehydrogenase (lipoamide)                 NaN      40
# MPZ Myelin protein zero (Charcot-Marie-Tooth ne...          NaN      23
# CBFA2 Core-binding factor, runt domain, alpha s...          NaN       3
# ...                                                         ...     ...
# FAS Del 2 mRNA                                              NaN       0
# mRNA encoding GPI-anchored protein p137                     NaN      32
# MOG Myelin oligodendrocyte glycoprotein {altern...          NaN       4
# PXR1 Peroxisome receptor 1                                  NaN       7
# SDC1 Syndecan 1                                             NaN      -2
# GCKR Glucokinase regulator                                  NaN       2
# GCKR Glucokinase regulator                                  NaN       7
# GCKR Glucokinase regulator                                  NaN     -30
# MT-MMP protein                                              NaN      -5
# MMP2 Matrix metalloproteinase 2                             NaN     -15
# Protein tyrosine phosphatase                                NaN      64
# Sp17 gene                                                   NaN       5
# mRNA (ocular albinism type 1 related)                       NaN      10
# BMPR-II                                                     NaN       9
# HISTONE H3.3                                                NaN     305
# Spermine synthase                                           NaN      40
# OBF-1 mRNA for octamer binding factor 1                     NaN       0
# RNA polymerase II subunit (hsRPB8) mRNA                     NaN     196
# P2Y1 purinoceptor mRNA, long form                           NaN      -1
# Chemokine HCC-1                                             NaN      12
# Chemokine HCC-1                                             NaN      -4
# Chemokine HCC-1                                             NaN      11
# GUC1A2 Guanylate cyclase 1, soluble, alpha 2                NaN       4
# NAD(P) transhydrogenase                                     NaN      33
# NAD(P) transhydrogenase                                     NaN      44
# Thimet oligopeptidase (metalloproteinase)                   NaN       4
# No cluster in current Unigene and no Genbank en...          NaN       1
# GCAP-II/uroguanylin precursor                               NaN      35
# BETA-DEFENSIN 1 PRECURSOR                                   NaN       7
# cre (spiked control)                                        NaN    4018
#
#                                                            ...          \
# BioB (spiked control)                                      ...
# BioC (spiked control)                                      ...
# BioD (spiked control)                                      ...
# CYP3A3 Cytochrome P450 IIIA3 (nifedipine oxidas...         ...
# CYP3A3 Cytochrome P450 IIIA3 (nifedipine oxidas...         ...
# CYP3A3 Cytochrome P450 IIIA3 (nifedipine oxidas...         ...
# PRNP Prion protein (p27-30) (Creutzfeld-Jakob d...         ...
# LTA Lymphotoxin alpha (formerly tumor necrosis ...         ...
# ADH2 Alcohol dehydrogenase 2 (class I), beta po...         ...
# CYP2C9 Cytochrome P450, subfamily IIC (mephenyt...         ...
# CYC1 Cytochrome c-1                                        ...
# ELASTASE IIIA PRECURSOR                                    ...
# CYP3A7 Cytochrome P450 IIIA7 (P450-HFLa)                   ...
# TYMS Thymidylate synthase                                  ...
# FECH Ferrochelatase (protoporphyria)                       ...
# T-CELL ANTIGEN CD7 PRECURSOR                               ...
# PSMA3 Proteasome component C3                              ...
# PSMA5 Proteasome component C5                              ...
# PROTEASOME COMPONENT C8                                    ...
# GAPD Glyceraldehyde-3-phosphate dehydrogenase              ...
# PRPS1 Phosphoribosyl pyrophosphate synthetase s...         ...
# FACL1 Long chain fatty acid acyl-coA ligase                ...
# PTAFR Platelet activating factor receptor                  ...
# POU1F1 POU domain, class 1, transcription facto...         ...
# ACAT1 Acetyl-Coenzyme A acetyltransferase 2 (ac...         ...
# MACS Myristoylated alanine-rich C-kinase substrate         ...
# MACS Myristoylated alanine-rich C-kinase substrate         ...
# OGDH Oxoglutarate dehydrogenase (lipoamide)                ...
# MPZ Myelin protein zero (Charcot-Marie-Tooth ne...         ...
# CBFA2 Core-binding factor, runt domain, alpha s...         ...
# ...                                                        ...
# FAS Del 2 mRNA                                             ...
# mRNA encoding GPI-anchored protein p137                    ...
# MOG Myelin oligodendrocyte glycoprotein {altern...         ...
# PXR1 Peroxisome receptor 1                                 ...
# SDC1 Syndecan 1                                            ...
# GCKR Glucokinase regulator                                 ...
# GCKR Glucokinase regulator                                 ...
# GCKR Glucokinase regulator                                 ...
# MT-MMP protein                                             ...
# MMP2 Matrix metalloproteinase 2                            ...
# Protein tyrosine phosphatase                               ...
# Sp17 gene                                                  ...
# mRNA (ocular albinism type 1 related)                      ...
# BMPR-II                                                    ...
# HISTONE H3.3                                               ...
# Spermine synthase                                          ...
# OBF-1 mRNA for octamer binding factor 1                    ...
# RNA polymerase II subunit (hsRPB8) mRNA                    ...
# P2Y1 purinoceptor mRNA, long form                          ...
# Chemokine HCC-1                                            ...
# Chemokine HCC-1                                            ...
# Chemokine HCC-1                                            ...
# GUC1A2 Guanylate cyclase 1, soluble, alpha 2               ...
# NAD(P) transhydrogenase                                    ...
# NAD(P) transhydrogenase                                    ...
# Thimet oligopeptidase (metalloproteinase)                  ...
# No cluster in current Unigene and no Genbank en...         ...
# GCAP-II/uroguanylin precursor                              ...
# BETA-DEFENSIN 1 PRECURSOR                                  ...
# cre (spiked control)                                       ...
#
#                                                     call.11  NB4_72_hrs  \
# BioB (spiked control)                                    -7         NaN
# BioC (spiked control)                                     2         NaN
# BioD (spiked control)                                   277         NaN
# CYP3A3 Cytochrome P450 IIIA3 (nifedipine oxidas...        7         NaN
# CYP3A3 Cytochrome P450 IIIA3 (nifedipine oxidas...       13         NaN
# CYP3A3 Cytochrome P450 IIIA3 (nifedipine oxidas...       14         NaN
# PRNP Prion protein (p27-30) (Creutzfeld-Jakob d...       10         NaN
# LTA Lymphotoxin alpha (formerly tumor necrosis ...       -6         NaN
# ADH2 Alcohol dehydrogenase 2 (class I), beta po...        7         NaN
# CYP2C9 Cytochrome P450, subfamily IIC (mephenyt...        5         NaN
# CYC1 Cytochrome c-1                                     460         NaN
# ELASTASE IIIA PRECURSOR                                  -6         NaN
# CYP3A7 Cytochrome P450 IIIA7 (P450-HFLa)                 -3         NaN
# TYMS Thymidylate synthase                               379         NaN
# FECH Ferrochelatase (protoporphyria)                     63         NaN
# T-CELL ANTIGEN CD7 PRECURSOR                             14         NaN
# PSMA3 Proteasome component C3                           160         NaN
# PSMA5 Proteasome component C5                           330         NaN
# PROTEASOME COMPONENT C8                                 272         NaN
# GAPD Glyceraldehyde-3-phosphate dehydrogenase           360         NaN
# PRPS1 Phosphoribosyl pyrophosphate synthetase s...       34         NaN
# FACL1 Long chain fatty acid acyl-coA ligase             896         NaN
# PTAFR Platelet activating factor receptor                28         NaN
# POU1F1 POU domain, class 1, transcription facto...        0         NaN
# ACAT1 Acetyl-Coenzyme A acetyltransferase 2 (ac...       52         NaN
# MACS Myristoylated alanine-rich C-kinase substrate      276         NaN
# MACS Myristoylated alanine-rich C-kinase substrate      262         NaN
# OGDH Oxoglutarate dehydrogenase (lipoamide)              50         NaN
# MPZ Myelin protein zero (Charcot-Marie-Tooth ne...       41         NaN
# CBFA2 Core-binding factor, runt domain, alpha s...       -5         NaN
# ...                                                     ...         ...
# FAS Del 2 mRNA                                            0         NaN
# mRNA encoding GPI-anchored protein p137                 122         NaN
# MOG Myelin oligodendrocyte glycoprotein {altern...        1         NaN
# PXR1 Peroxisome receptor 1                               11         NaN
# SDC1 Syndecan 1                                         -17         NaN
# GCKR Glucokinase regulator                               21         NaN
# GCKR Glucokinase regulator                               25         NaN
# GCKR Glucokinase regulator                              -39         NaN
# MT-MMP protein                                           -3         NaN
# MMP2 Matrix metalloproteinase 2                         -31         NaN
# Protein tyrosine phosphatase                             61         NaN
# Sp17 gene                                                -4         NaN
# mRNA (ocular albinism type 1 related)                    13         NaN
# BMPR-II                                                   3         NaN
# HISTONE H3.3                                            313         NaN
# Spermine synthase                                       108         NaN
# OBF-1 mRNA for octamer binding factor 1                  -1         NaN
# RNA polymerase II subunit (hsRPB8) mRNA                 113         NaN
# P2Y1 purinoceptor mRNA, long form                         7         NaN
# Chemokine HCC-1                                          15         NaN
# Chemokine HCC-1                                           0         NaN
# Chemokine HCC-1                                           0         NaN
# GUC1A2 Guanylate cyclase 1, soluble, alpha 2              1         NaN
# NAD(P) transhydrogenase                                  29         NaN
# NAD(P) transhydrogenase                                  27         NaN
# Thimet oligopeptidase (metalloproteinase)               -10         NaN
# No cluster in current Unigene and no Genbank en...       30         NaN
# GCAP-II/uroguanylin precursor                            25         NaN
# BETA-DEFENSIN 1 PRECURSOR                                 2         NaN
# cre (spiked control)                                   4586         NaN
#
#                                                     call.12  Jurkat_0_hrs  \
# BioB (spiked control)                                    -5           NaN
# BioC (spiked control)                                     1           NaN
# BioD (spiked control)                                   210           NaN
# CYP3A3 Cytochrome P450 IIIA3 (nifedipine oxidas...        1           NaN
# CYP3A3 Cytochrome P450 IIIA3 (nifedipine oxidas...        6           NaN
# CYP3A3 Cytochrome P450 IIIA3 (nifedipine oxidas...        6           NaN
# PRNP Prion protein (p27-30) (Creutzfeld-Jakob d...       11           NaN
# LTA Lymphotoxin alpha (formerly tumor necrosis ...       -9           NaN
# ADH2 Alcohol dehydrogenase 2 (class I), beta po...        3           NaN
# CYP2C9 Cytochrome P450, subfamily IIC (mephenyt...        3           NaN
# CYC1 Cytochrome c-1                                     216           NaN
# ELASTASE IIIA PRECURSOR                                 -13           NaN
# CYP3A7 Cytochrome P450 IIIA7 (P450-HFLa)                  5           NaN
# TYMS Thymidylate synthase                              1256           NaN
# FECH Ferrochelatase (protoporphyria)                    163           NaN
# T-CELL ANTIGEN CD7 PRECURSOR                            216           NaN
# PSMA3 Proteasome component C3                           249           NaN
# PSMA5 Proteasome component C5                           782           NaN
# PROTEASOME COMPONENT C8                                 998           NaN
# GAPD Glyceraldehyde-3-phosphate dehydrogenase           585           NaN
# PRPS1 Phosphoribosyl pyrophosphate synthetase s...      254           NaN
# FACL1 Long chain fatty acid acyl-coA ligase              13           NaN
# PTAFR Platelet activating factor receptor                 2           NaN
# POU1F1 POU domain, class 1, transcription facto...        3           NaN
# ACAT1 Acetyl-Coenzyme A acetyltransferase 2 (ac...      118           NaN
# MACS Myristoylated alanine-rich C-kinase substrate        4           NaN
# MACS Myristoylated alanine-rich C-kinase substrate       -2           NaN
# OGDH Oxoglutarate dehydrogenase (lipoamide)              39           NaN
# MPZ Myelin protein zero (Charcot-Marie-Tooth ne...       29           NaN
# CBFA2 Core-binding factor, runt domain, alpha s...       19           NaN
# ...                                                     ...           ...
# FAS Del 2 mRNA                                           11           NaN
# mRNA encoding GPI-anchored protein p137                 163           NaN
# MOG Myelin oligodendrocyte glycoprotein {altern...       10           NaN
# PXR1 Peroxisome receptor 1                               49           NaN
# SDC1 Syndecan 1                                         -12           NaN
# GCKR Glucokinase regulator                                7           NaN
# GCKR Glucokinase regulator                               30           NaN
# GCKR Glucokinase regulator                              -53           NaN
# MT-MMP protein                                          -26           NaN
# MMP2 Matrix metalloproteinase 2                         -28           NaN
# Protein tyrosine phosphatase                             25           NaN
# Sp17 gene                                                32           NaN
# mRNA (ocular albinism type 1 related)                     7           NaN
# BMPR-II                                                  26           NaN
# HISTONE H3.3                                            498           NaN
# Spermine synthase                                       160           NaN
# OBF-1 mRNA for octamer binding factor 1                   1           NaN
# RNA polymerase II subunit (hsRPB8) mRNA                 282           NaN
# P2Y1 purinoceptor mRNA, long form                        -2           NaN
# Chemokine HCC-1                                           6           NaN
# Chemokine HCC-1                                          17           NaN
# Chemokine HCC-1                                         -10           NaN
# GUC1A2 Guanylate cyclase 1, soluble, alpha 2             -1           NaN
# NAD(P) transhydrogenase                                  41           NaN
# NAD(P) transhydrogenase                                  53           NaN
# Thimet oligopeptidase (metalloproteinase)                -5           NaN
# No cluster in current Unigene and no Genbank en...        4           NaN
# GCAP-II/uroguanylin precursor                            36           NaN
# BETA-DEFENSIN 1 PRECURSOR                                -3           NaN
# cre (spiked control)                                   3502           NaN
#
#                                                     call.13  Jurkat_0.5_hrs  \
# BioB (spiked control)                                    -5             NaN
# BioC (spiked control)                                     3             NaN
# BioD (spiked control)                                   192             NaN
# CYP3A3 Cytochrome P450 IIIA3 (nifedipine oxidas...       10             NaN
# CYP3A3 Cytochrome P450 IIIA3 (nifedipine oxidas...       12             NaN
# CYP3A3 Cytochrome P450 IIIA3 (nifedipine oxidas...       -3             NaN
# PRNP Prion protein (p27-30) (Creutzfeld-Jakob d...       19             NaN
# LTA Lymphotoxin alpha (formerly tumor necrosis ...        4             NaN
# ADH2 Alcohol dehydrogenase 2 (class I), beta po...        0             NaN
# CYP2C9 Cytochrome P450, subfamily IIC (mephenyt...        2             NaN
# CYC1 Cytochrome c-1                                     355             NaN
# ELASTASE IIIA PRECURSOR                                 -14             NaN
# CYP3A7 Cytochrome P450 IIIA7 (P450-HFLa)                 -5             NaN
# TYMS Thymidylate synthase                              1073             NaN
# FECH Ferrochelatase (protoporphyria)                    129             NaN
# T-CELL ANTIGEN CD7 PRECURSOR                            195             NaN
# PSMA3 Proteasome component C3                           274             NaN
# PSMA5 Proteasome component C5                           871             NaN
# PROTEASOME COMPONENT C8                                1025             NaN
# GAPD Glyceraldehyde-3-phosphate dehydrogenase           530             NaN
# PRPS1 Phosphoribosyl pyrophosphate synthetase s...      186             NaN
# FACL1 Long chain fatty acid acyl-coA ligase               1             NaN
# PTAFR Platelet activating factor receptor                -1             NaN
# POU1F1 POU domain, class 1, transcription facto...       -6             NaN
# ACAT1 Acetyl-Coenzyme A acetyltransferase 2 (ac...       73             NaN
# MACS Myristoylated alanine-rich C-kinase substrate        0             NaN
# MACS Myristoylated alanine-rich C-kinase substrate       -3             NaN
# OGDH Oxoglutarate dehydrogenase (lipoamide)              38             NaN
# MPZ Myelin protein zero (Charcot-Marie-Tooth ne...       22             NaN
# CBFA2 Core-binding factor, runt domain, alpha s...       20             NaN
# ...                                                     ...             ...
# FAS Del 2 mRNA                                           21             NaN
# mRNA encoding GPI-anchored protein p137                 119             NaN
# MOG Myelin oligodendrocyte glycoprotein {altern...        5             NaN
# PXR1 Peroxisome receptor 1                               48             NaN
# SDC1 Syndecan 1                                          -7             NaN
# GCKR Glucokinase regulator                               29             NaN
# GCKR Glucokinase regulator                               57             NaN
# GCKR Glucokinase regulator                              -85             NaN
# MT-MMP protein                                          -31             NaN
# MMP2 Matrix metalloproteinase 2                         -16             NaN
# Protein tyrosine phosphatase                             86             NaN
# Sp17 gene                                                27             NaN
# mRNA (ocular albinism type 1 related)                    14             NaN
# BMPR-II                                                   4             NaN
# HISTONE H3.3                                            412             NaN
# Spermine synthase                                        68             NaN
# OBF-1 mRNA for octamer binding factor 1                   3             NaN
# RNA polymerase II subunit (hsRPB8) mRNA                 217             NaN
# P2Y1 purinoceptor mRNA, long form                        -3             NaN
# Chemokine HCC-1                                           2             NaN
# Chemokine HCC-1                                          -3             NaN
# Chemokine HCC-1                                           4             NaN
# GUC1A2 Guanylate cyclase 1, soluble, alpha 2              6             NaN
# NAD(P) transhydrogenase                                  36             NaN
# NAD(P) transhydrogenase                                  57             NaN
# Thimet oligopeptidase (metalloproteinase)                 1             NaN
# No cluster in current Unigene and no Genbank en...      -15             NaN
# GCAP-II/uroguanylin precursor                            15             NaN
# BETA-DEFENSIN 1 PRECURSOR                                 6             NaN
# cre (spiked control)                                   3657             NaN
#
#                                                     call.14  Jurkat_4_hrs  \
# BioB (spiked control)                                    -2           NaN
# BioC (spiked control)                                     3           NaN
# BioD (spiked control)                                   190           NaN
# CYP3A3 Cytochrome P450 IIIA3 (nifedipine oxidas...        1           NaN
# CYP3A3 Cytochrome P450 IIIA3 (nifedipine oxidas...       12           NaN
# CYP3A3 Cytochrome P450 IIIA3 (nifedipine oxidas...       10           NaN
# PRNP Prion protein (p27-30) (Creutzfeld-Jakob d...       24           NaN
# LTA Lymphotoxin alpha (formerly tumor necrosis ...       -4           NaN
# ADH2 Alcohol dehydrogenase 2 (class I), beta po...        7           NaN
# CYP2C9 Cytochrome P450, subfamily IIC (mephenyt...       -1           NaN
# CYC1 Cytochrome c-1                                     234           NaN
# ELASTASE IIIA PRECURSOR                                   9           NaN
# CYP3A7 Cytochrome P450 IIIA7 (P450-HFLa)                 -2           NaN
# TYMS Thymidylate synthase                              1027           NaN
# FECH Ferrochelatase (protoporphyria)                     92           NaN
# T-CELL ANTIGEN CD7 PRECURSOR                            182           NaN
# PSMA3 Proteasome component C3                           270           NaN
# PSMA5 Proteasome component C5                           777           NaN
# PROTEASOME COMPONENT C8                                 984           NaN
# GAPD Glyceraldehyde-3-phosphate dehydrogenase           498           NaN
# PRPS1 Phosphoribosyl pyrophosphate synthetase s...      205           NaN
# FACL1 Long chain fatty acid acyl-coA ligase               8           NaN
# PTAFR Platelet activating factor receptor                 5           NaN
# POU1F1 POU domain, class 1, transcription facto...       -1           NaN
# ACAT1 Acetyl-Coenzyme A acetyltransferase 2 (ac...      101           NaN
# MACS Myristoylated alanine-rich C-kinase substrate       -5           NaN
# MACS Myristoylated alanine-rich C-kinase substrate       -4           NaN
# OGDH Oxoglutarate dehydrogenase (lipoamide)              46           NaN
# MPZ Myelin protein zero (Charcot-Marie-Tooth ne...       30           NaN
# CBFA2 Core-binding factor, runt domain, alpha s...       16           NaN
# ...                                                     ...           ...
# FAS Del 2 mRNA                                           16           NaN
# mRNA encoding GPI-anchored protein p137                 142           NaN
# MOG Myelin oligodendrocyte glycoprotein {altern...        2           NaN
# PXR1 Peroxisome receptor 1                               12           NaN
# SDC1 Syndecan 1                                          -5           NaN
# GCKR Glucokinase regulator                               15           NaN
# GCKR Glucokinase regulator                               26           NaN
# GCKR Glucokinase regulator                              -52           NaN
# MT-MMP protein                                          -26           NaN
# MMP2 Matrix metalloproteinase 2                         -34           NaN
# Protein tyrosine phosphatase                             37           NaN
# Sp17 gene                                                28           NaN
# mRNA (ocular albinism type 1 related)                     2           NaN
# BMPR-II                                                  24           NaN
# HISTONE H3.3                                            536           NaN
# Spermine synthase                                       162           NaN
# OBF-1 mRNA for octamer binding factor 1                  -1           NaN
# RNA polymerase II subunit (hsRPB8) mRNA                 313           NaN
# P2Y1 purinoceptor mRNA, long form                         2           NaN
# Chemokine HCC-1                                          22           NaN
# Chemokine HCC-1                                           6           NaN
# Chemokine HCC-1                                           2           NaN
# GUC1A2 Guanylate cyclase 1, soluble, alpha 2              3           NaN
# NAD(P) transhydrogenase                                  26           NaN
# NAD(P) transhydrogenase                                  37           NaN
# Thimet oligopeptidase (metalloproteinase)                -4           NaN
# No cluster in current Unigene and no Genbank en...        9           NaN
# GCAP-II/uroguanylin precursor                            22           NaN
# BETA-DEFENSIN 1 PRECURSOR                                 4           NaN
# cre (spiked control)                                   3321           NaN
#
#                                                     call.15  \
# BioB (spiked control)                                    -3
# BioC (spiked control)                                    -3
# BioD (spiked control)                                   152
# CYP3A3 Cytochrome P450 IIIA3 (nifedipine oxidas...        7
# CYP3A3 Cytochrome P450 IIIA3 (nifedipine oxidas...       13
# CYP3A3 Cytochrome P450 IIIA3 (nifedipine oxidas...       13
# PRNP Prion protein (p27-30) (Creutzfeld-Jakob d...       21
# LTA Lymphotoxin alpha (formerly tumor necrosis ...       11
# ADH2 Alcohol dehydrogenase 2 (class I), beta po...       10
# CYP2C9 Cytochrome P450, subfamily IIC (mephenyt...        3
# CYC1 Cytochrome c-1                                     181
# ELASTASE IIIA PRECURSOR                                  -9
# CYP3A7 Cytochrome P450 IIIA7 (P450-HFLa)                 -1
# TYMS Thymidylate synthase                               967
# FECH Ferrochelatase (protoporphyria)                     56
# T-CELL ANTIGEN CD7 PRECURSOR                            108
# PSMA3 Proteasome component C3                           271
# PSMA5 Proteasome component C5                           951
# PROTEASOME COMPONENT C8                                 808
# GAPD Glyceraldehyde-3-phosphate dehydrogenase           527
# PRPS1 Phosphoribosyl pyrophosphate synthetase s...      132
# FACL1 Long chain fatty acid acyl-coA ligase              10
# PTAFR Platelet activating factor receptor                -2
# POU1F1 POU domain, class 1, transcription facto...       -3
# ACAT1 Acetyl-Coenzyme A acetyltransferase 2 (ac...       56
# MACS Myristoylated alanine-rich C-kinase substrate       -1
# MACS Myristoylated alanine-rich C-kinase substrate        4
# OGDH Oxoglutarate dehydrogenase (lipoamide)              39
# MPZ Myelin protein zero (Charcot-Marie-Tooth ne...       35
# CBFA2 Core-binding factor, runt domain, alpha s...        9
# ...                                                     ...
# FAS Del 2 mRNA                                           19
# mRNA encoding GPI-anchored protein p137                 115
# MOG Myelin oligodendrocyte glycoprotein {altern...       -1
# PXR1 Peroxisome receptor 1                                9
# SDC1 Syndecan 1                                         -18
# GCKR Glucokinase regulator                               20
# GCKR Glucokinase regulator                               28
# GCKR Glucokinase regulator                              -62
# MT-MMP protein                                          -16
# MMP2 Matrix metalloproteinase 2                         -26
# Protein tyrosine phosphatase                             59
# Sp17 gene                                                42
# mRNA (ocular albinism type 1 related)                     2
# BMPR-II                                                  25
# HISTONE H3.3                                            582
# Spermine synthase                                       259
# OBF-1 mRNA for octamer binding factor 1                   3
# RNA polymerase II subunit (hsRPB8) mRNA                 226
# P2Y1 purinoceptor mRNA, long form                        -1
# Chemokine HCC-1                                          23
# Chemokine HCC-1                                          14
# Chemokine HCC-1                                          21
# GUC1A2 Guanylate cyclase 1, soluble, alpha 2             -2
# NAD(P) transhydrogenase                                  27
# NAD(P) transhydrogenase                                  34
# Thimet oligopeptidase (metalloproteinase)                 0
# No cluster in current Unigene and no Genbank en...        3
# GCAP-II/uroguanylin precursor                            21
# BETA-DEFENSIN 1 PRECURSOR                                -7
# cre (spiked control)                                   3223
#
#                                                     Jurkat_24_hrs call
# BioB (spiked control)                                              NaN
# BioC (spiked control)                                              NaN
# BioD (spiked control)                                              NaN
# CYP3A3 Cytochrome P450 IIIA3 (nifedipine oxidas...                 NaN
# CYP3A3 Cytochrome P450 IIIA3 (nifedipine oxidas...                 NaN
# CYP3A3 Cytochrome P450 IIIA3 (nifedipine oxidas...                 NaN
# PRNP Prion protein (p27-30) (Creutzfeld-Jakob d...                 NaN
# LTA Lymphotoxin alpha (formerly tumor necrosis ...                 NaN
# ADH2 Alcohol dehydrogenase 2 (class I), beta po...                 NaN
# CYP2C9 Cytochrome P450, subfamily IIC (mephenyt...                 NaN
# CYC1 Cytochrome c-1                                                NaN
# ELASTASE IIIA PRECURSOR                                            NaN
# CYP3A7 Cytochrome P450 IIIA7 (P450-HFLa)                           NaN
# TYMS Thymidylate synthase                                          NaN
# FECH Ferrochelatase (protoporphyria)                               NaN
# T-CELL ANTIGEN CD7 PRECURSOR                                       NaN
# PSMA3 Proteasome component C3                                      NaN
# PSMA5 Proteasome component C5                                      NaN
# PROTEASOME COMPONENT C8                                            NaN
# GAPD Glyceraldehyde-3-phosphate dehydrogenase                      NaN
# PRPS1 Phosphoribosyl pyrophosphate synthetase s...                 NaN
# FACL1 Long chain fatty acid acyl-coA ligase                        NaN
# PTAFR Platelet activating factor receptor                          NaN
# POU1F1 POU domain, class 1, transcription facto...                 NaN
# ACAT1 Acetyl-Coenzyme A acetyltransferase 2 (ac...                 NaN
# MACS Myristoylated alanine-rich C-kinase substrate                 NaN
# MACS Myristoylated alanine-rich C-kinase substrate                 NaN
# OGDH Oxoglutarate dehydrogenase (lipoamide)                        NaN
# MPZ Myelin protein zero (Charcot-Marie-Tooth ne...                 NaN
# CBFA2 Core-binding factor, runt domain, alpha s...                 NaN
# ...                                                                ...
# FAS Del 2 mRNA                                                     NaN
# mRNA encoding GPI-anchored protein p137                            NaN
# MOG Myelin oligodendrocyte glycoprotein {altern...                 NaN
# PXR1 Peroxisome receptor 1                                         NaN
# SDC1 Syndecan 1                                                    NaN
# GCKR Glucokinase regulator                                         NaN
# GCKR Glucokinase regulator                                         NaN
# GCKR Glucokinase regulator                                         NaN
# MT-MMP protein                                                     NaN
# MMP2 Matrix metalloproteinase 2                                    NaN
# Protein tyrosine phosphatase                                       NaN
# Sp17 gene                                                          NaN
# mRNA (ocular albinism type 1 related)                              NaN
# BMPR-II                                                            NaN
# HISTONE H3.3                                                       NaN
# Spermine synthase                                                  NaN
# OBF-1 mRNA for octamer binding factor 1                            NaN
# RNA polymerase II subunit (hsRPB8) mRNA                            NaN
# P2Y1 purinoceptor mRNA, long form                                  NaN
# Chemokine HCC-1                                                    NaN
# Chemokine HCC-1                                                    NaN
# Chemokine HCC-1                                                    NaN
# GUC1A2 Guanylate cyclase 1, soluble, alpha 2                       NaN
# NAD(P) transhydrogenase                                            NaN
# NAD(P) transhydrogenase                                            NaN
# Thimet oligopeptidase (metalloproteinase)                          NaN
# No cluster in current Unigene and no Genbank en...                 NaN
# GCAP-II/uroguanylin precursor                                      NaN
# BETA-DEFENSIN 1 PRECURSOR                                          NaN
# cre (spiked control)                                               NaN
#
# [7229 rows x 35 columns]

# %%
sum(uarray["HL60_0_hrs"] != uarray["HL60_0.5_hrs"])
# Out:
# 1070

# %%
uarray[["HL60_0_hrs"]), "HL60_0.5_hrs"]]
# Out:
#   File "<ipython-input-29-bbe9c230930d>", line 1
#     uarray[ord(["HL60_0_hrs"]), "HL60_0.5_hrs"]]
#                                                ^
# SyntaxError: invalid syntax

# %%
#>>> obs = np.array([[16, 18, 16, 14, 12, 12], [32, 24, 16, 28, 20, 24]]).T
#>>> obs.shape
#(6, 2)
from scipy.stats.mstats import chisquare
chisquare(uarray[["HL60_0_hrs", "HL60_0.5_hrs"]])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-047b69139a8c> in <module>()
#       3 #(6, 2)
#       4 from scipy.stats.mstats import chisquare
# ----> 5 chisquare(uarray[["HL60_0_hrs", "HL60_0.5_hrs"]])
#
# NameError: name 'uarray' is not defined
